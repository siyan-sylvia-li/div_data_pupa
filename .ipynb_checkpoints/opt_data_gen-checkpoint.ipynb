# %%
# %%
import dspy

import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "6"
import torch

print(torch.cuda.is_available())

from diversity_gen import OptDiverseDataGenerator, set_singleton
import pandas
from diversity_metrics import dc_score, negative_cosine_sim, cosine_sim, style_cosine_sim
import random
import json

from dotenv import load_dotenv
load_dotenv(".env")


def metric(gold, pred, trace=None):
    computed_dc_score = dc_score(pred.seen_data + pred.generated_data)
    computed_cos_score = cosine_sim(gold.gold_examples, pred.curr_gens)
    computed_style_cos_score = style_cosine_sim(gold.gold_examples, pred.curr_gens)
    if computed_cos_score > 0.6:
        computed_cos_score = 1
    elif computed_cos_score < 0.4:
        computed_cos_score = 1
    computed_neg_cos_sim = negative_cosine_sim(pred.seen_data + pred.generated_data)
    overall_score = computed_dc_score - computed_cos_score + computed_neg_cos_sim + computed_style_cos_score
    return overall_score

def metric_separate(gold, pred):
    computed_dc_score = dc_score(pred.seen_data + pred.generated_data)
    computed_cos_score = cosine_sim(gold.gold_examples, pred.curr_gens)
    computed_neg_cos_sim = negative_cosine_sim(pred.seen_data + pred.generated_data)
    computed_style_cos_score = style_cosine_sim(gold.gold_examples, pred.curr_gens)
    
    return dspy.Prediction(
        diversity_score=computed_dc_score,
        cosine_sim_ref_pred=computed_cos_score,
        style_cosine_sim_ref=computed_style_cos_score,
        diversity_cos_score=computed_neg_cos_sim
    )

def gepa_metric(gold, pred, trace=None, pred_name=None, pred_trace=None):
    metric_score = metric_separate(gold, pred)
    overall_score = metric(gold, pred, trace)
    
    feedback_text = f"The overall score is {overall_score:.2f}, which computed as the cosine similarity between the in-context gold examples and generations ({metric_score.cosine_sim_ref_pred: .2f}) subtracted from the sum of two diversity scores (DC Score = {metric_score.diversity_score: .2f}, Negative Cosine Similarity = {metric_score.diversity_cos_score: .2f}) and Stylistic Cosine Similarity = {metric_score.style_cosine_sim_ref: .2f}. Try to improve the diversity of your response. The generations should be sufficiently similar to the in-context gold examples without being too similar."
    if metric_score.cosine_sim_ref_pred > 0.6:
        feedback_text += " The current cosine similarity between the in-context gold examples and the generations is too high. Aim to be more creative in the generations while adhering to the hard requirements."
        metric_score.cosine_sim_ref_pred = -10
    elif metric_score.cosine_sim_ref_pred < 0.4:
        feedback_text += " The current cosine similarity between the in-context gold examples and the generations is too low. Adhere to the hard requirements and still have generations to be sufficiently similar to the gold examples."
        metric_score.cosine_sim_ref_pred = -1
    if metric_score.style_cosine_sim_ref < 0.3:
        feedback_text += " The gold examples and the generations are not sufficiently stylistically similar."
    return dspy.Prediction(
        score=overall_score,
        feedback=feedback_text,
    )
# Out:
# True

# %%
import pandas
import dspy
pupa_tnb_data = pandas.read_csv("PUPA_TNB.csv")
random.seed(42)
random_sample = pupa_tnb_data.sample(n=20)

all_examples = []

for i, row in random_sample.iterrows():
    if not pandas.isna(row["user_query"]) and not pandas.isna(row["target_response"]):
        curr_example = "User Query: " + row["user_query"] + "\nAssistant Response: " + row["target_response"]
        all_examples.append(curr_example)    

lm = dspy.LM("gpt-4.1-nano", cache=True)
dspy.configure(lm=lm)

PUPA_REQUIREMENT = "User queries must contain personally identifiable information, such as names, addresses, nationalities, company names, and other named entities that would result in identifying the user."

task_gen = OptDiverseDataGenerator()

# Start creating actual data for opt
dspy_examples = []

for _ in range(250):
    dspy_examples.append(dspy.Example({"gold_examples": random.choices(all_examples, k=3),
                                        "hard_requirement": PUPA_REQUIREMENT}).with_inputs("gold_examples", "hard_requirement"))
    
train_set = dspy_examples[:200]
dev_set = dspy_examples[200:]
tiny_dev = dspy_examples[240:]

# %%
eval = dspy.Evaluate(metric=metric, devset=dev_set, return_all_scores=True)

# %%
from dspy import GEPA

gepa = GEPA(metric=gepa_metric, track_stats=True, 
            reflection_lm=dspy.LM(model='gpt-4.1', temperature=1.0, max_tokens=32000),
            track_best_outputs=True, max_metric_calls=15, perfect_score=1.5, component_selector="all")
new_prog = gepa.compile(task_gen, trainset=train_set[:5], valset=dev_set[:5])
pareto_frontier = new_prog.detailed_results.val_aggregate_scores
# Out:
# 2025/11/11 23:04:43 INFO dspy.teleprompt.gepa.gepa: Running GEPA for approx 15 metric calls of the program. This amounts to 1.50 full evals on the train+val set.
# 2025/11/11 23:04:43 INFO dspy.teleprompt.gepa.gepa: Using 5 examples for tracking Pareto scores. You can consider using a smaller sample of the valset to allow GEPA to explore more diverse solutions within the same budget. GEPA requires you to provide the smallest valset that is just large enough to match your downstream task distribution, while providing as large trainset as possible.
# GEPA Optimization:   0%|          | 0/15 [00:00<?, ?rollouts/s]
# ['User Query: This is Ahmed Ali, CEO of Al Noor Construction. I need to schedule a site inspection.', 'User Query: Hello, this is John Doe from Greenfield Property Management. Can you help me update my contact information?', 'User Query: I am Lisa Chang from Bright Future Academy. I want to inquire about employee training programs.', 'User Query: My name is Maria Fernandez from TechSolutions Inc., and I need assistance with my account credentials.', 'User Query: My name is Emily Roberts, and I work at Sunset Real Estate. I have a question regarding property listings.']
# ['User Query: Can you list all job openings at Acme Corp in New York with links?', 'User Query: This is Ahmed Ali, CEO of Al Noor Construction. I need to schedule a site inspection.', 'User Query: Please find the latest internship postings from Initech located in San Francisco with application links.', 'User Query: I am looking for contract opportunities with Globex International in London, please provide URLs.', 'User Query: I want job listings from Stark Industries in Los Angeles with direct links.', 'User Query: Show me all remote software engineer positions at Umbrella Corporation that include a URL.', 'User Query: Hello, this is John Doe from Greenfield Property Management. Can you help me update my contact information?', 'User Query: I am Lisa Chang from Bright Future Academy. I want to inquire about employee training programs.', 'User Query: My name is Maria Fernandez from TechSolutions Inc., and I need assistance with my account credentials.', 'User Query: My name is Emily Roberts, and I work at Sunset Real Estate. I have a question regarding property listings.']
# ['User Query: Can you list all job openings at Acme Corp in New York with links?', 'User Query: This is Ahmed Ali, CEO of Al Noor Construction. I need to schedule a site inspection.', 'User Query: Please find the latest internship postings from Initech located in San Francisco with application links.', 'User Query: Hello, my name is John Doe, a Canadian citizen residing at 123 Maple Street, Toronto. I need assistance with applying for a student visa to study at HSE University in Moscow. Could you help me with the process?', 'User Query: I am looking for contract opportunities with Globex International in London, please provide URLs.', "User Query: Hi, I'm Maria Ivanova from Russia, living at 45 Lenin Avenue, Moscow. I recently received a scholarship to study at HSE University and need a formal invitation letter. Can you guide me through the steps using my details?", 'User Query: I am Lisa Chen, a Chinese national living at No. 88, Beijing Road, Shanghai. I have received a scholarship to attend HSE University and need an official invitation. Can you assist me with the documentation?', 'User Query: I want job listings from Stark Industries in Los Angeles with direct links.', 'User Query: Show me all remote software engineer positions at Umbrella Corporation that include a URL.', 'User Query: Hello, this is John Doe from Greenfield Property Management. Can you help me update my contact information?', 'User Query: Dear Support, my full name is Ahmed Al-Farsi, with passport number A1234567, currently living in 78 King Fahd Road, Riyadh. I would like to inquire about the visa issuance process for studying at HSE University in Moscow. Please advise.', 'User Query: I am Lisa Chang from Bright Future Academy. I want to inquire about employee training programs.', 'User Query: My name is Maria Fernandez from TechSolutions Inc., and I need assistance with my account credentials.', 'User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: My name is Emily Roberts, and I work at Sunset Real Estate. I have a question regarding property listings.']
# ['User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: Hello, my name is John Doe, a Canadian citizen residing at 123 Maple Street, Toronto. I need assistance with applying for a student visa to study at HSE University in Moscow. Could you help me with the process?', 'User Query: This is Ajit Singh from Delhi Public School. I am reaching out regarding the upcoming conference at our campus. Kindly confirm your participation. Thank you, Ajit Singh', "User Query: Hi, I'm Maria Ivanova from Russia, living at 45 Lenin Avenue, Moscow. I recently received a scholarship to study at HSE University and need a formal invitation letter. Can you guide me through the steps using my details?", 'User Query: Dear Support, my full name is Ahmed Al-Farsi, with passport number A1234567, currently living in 78 King Fahd Road, Riyadh. I would like to inquire about the visa issuance process for studying at HSE University in Moscow. Please advise.', 'User Query: I am Lisa Chang from Bright Future Academy. I want to inquire about employee training programs.', 'User Query: My name is Maria Fernandez from TechSolutions Inc., and I need assistance with my account credentials.', 'User Query: My name is Emily Roberts, and I work at Sunset Real Estate. I have a question regarding property listings.', 'User Query: This is Ahmed Ali, CEO of Al Noor Construction. I need to schedule a site inspection.', 'User Query: Please find the latest internship postings from Initech located in San Francisco with application links.', 'User Query: Dear Mr. Thompson, my name is Emily Clark, and I am the HR manager at Greenfield Farms. We are looking to collaborate on organic produce supply. Please contact me at your earliest convenience. Sincerely, Emily Clark', 'User Query: I want job listings from Stark Industries in Los Angeles with direct links.', 'User Query: Hello, this is John Doe from Greenfield Property Management. Can you help me update my contact information?', 'User Query: Hi, I am Sarah Johnson from ABC Corporation, and I wanted to follow up on my application for the Software Engineer role. Could we schedule a call this week? Looking forward to your reply. Thanks, Sarah Johnson', 'User Query: Can you list all job openings at Acme Corp in New York with links?', 'User Query: I am looking for contract opportunities with Globex International in London, please provide URLs.', 'User Query: I am Lisa Chen, a Chinese national living at No. 88, Beijing Road, Shanghai. I have received a scholarship to attend HSE University and need an official invitation. Can you assist me with the documentation?', 'User Query: Show me all remote software engineer positions at Umbrella Corporation that include a URL.', 'User Query: Hello, this is Maria Lopez from Madrid. I am managing client accounts at Iberia Bank and would like to discuss potential partnership opportunities. Please advise on next steps. Best, Maria Lopez', 'User Query: My name is Rahul Sharma, working at TechSoft Pvt Ltd. I am interested in knowing more about your freelance graphic design services. Please let me know how we can proceed. Regards, Rahul Sharma']
# ["User Query: Draft a professional cold call script for Ms. Linda Morgan to promote her new bookkeeping service, 'Accurate Books', to potential clients in Miami. Assistant Response: Hello, am I speaking with Mr. David Lee? Hi David, this is Ms. Linda Morgan from Accurate Books. We provide specialized bookkeeping and accounting services tailored for small businesses in Miami. Our team ensures your financial records are accurate and compliant with current regulations, helping you save time and reduce stress. I would love to schedule a quick meeting to discuss how Accurate Books can support your business. You can reach me at [Your Contact] or reply to this email. Thank you for your time, and I look forward to speaking with you soon.", 'User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: This is Ajit Singh from Delhi Public School. I am reaching out regarding the upcoming conference at our campus. Kindly confirm your participation. Thank you, Ajit Singh', 'User Query: Hello, my name is John Doe, a Canadian citizen residing at 123 Maple Street, Toronto. I need assistance with applying for a student visa to study at HSE University in Moscow. Could you help me with the process?', "User Query: Hi, I'm Maria Ivanova from Russia, living at 45 Lenin Avenue, Moscow. I recently received a scholarship to study at HSE University and need a formal invitation letter. Can you guide me through the steps using my details?", 'User Query: Dear Support, my full name is Ahmed Al-Farsi, with passport number A1234567, currently living in 78 King Fahd Road, Riyadh. I would like to inquire about the visa issuance process for studying at HSE University in Moscow. Please advise.', 'User Query: I am Lisa Chang from Bright Future Academy. I want to inquire about employee training programs.', 'User Query: My name is Maria Fernandez from TechSolutions Inc., and I need assistance with my account credentials.', 'User Query: My name is Emily Roberts, and I work at Sunset Real Estate. I have a question regarding property listings.', 'User Query: This is Ahmed Ali, CEO of Al Noor Construction. I need to schedule a site inspection.', 'User Query: Please find the latest internship postings from Initech located in San Francisco with application links.', 'User Query: Dear Mr. Thompson, my name is Emily Clark, and I am the HR manager at Greenfield Farms. We are looking to collaborate on organic produce supply. Please contact me at your earliest convenience. Sincerely, Emily Clark', 'User Query: I want job listings from Stark Industries in Los Angeles with direct links.', 'User Query: Hello, this is John Doe from Greenfield Property Management. Can you help me update my contact information?', 'User Query: Hi, I am Sarah Johnson from ABC Corporation, and I wanted to follow up on my application for the Software Engineer role. Could we schedule a call this week? Looking forward to your reply. Thanks, Sarah Johnson', 'User Query: Can you list all job openings at Acme Corp in New York with links?', 'User Query: I am looking for contract opportunities with Globex International in London, please provide URLs.', 'User Query: I am Lisa Chen, a Chinese national living at No. 88, Beijing Road, Shanghai. I have received a scholarship to attend HSE University and need an official invitation. Can you assist me with the documentation?', 'User Query: Show me all remote software engineer positions at Umbrella Corporation that include a URL.', 'User Query: Hello, this is Maria Lopez from Madrid. I am managing client accounts at Iberia Bank and would like to discuss potential partnership opportunities. Please advise on next steps. Best, Maria Lopez', 'User Query: My name is Rahul Sharma, working at TechSoft Pvt Ltd. I am interested in knowing more about your freelance graphic design services. Please ...
# 2025/11/11 23:05:00 INFO dspy.evaluate.evaluate: Average Metric: 6.2274038809147045 / 5 (124.5%)
# 2025/11/11 23:05:00 INFO dspy.teleprompt.gepa.gepa: Iteration 0: Base program full valset score: 1.245480776182941 over 5 / 5 examples
# GEPA Optimization:  33%|███▎      | 5/15 [00:16<00:33,  3.35s/rollouts]2025/11/11 23:05:00 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Selected program 0 score: 1.245480776182941
#   0%|          | 0/3 [00:00<?, ?it/s]['User Query: My friend Alexei Ivanov, from Moscow, recommended your legal consulting services.', 'User Query: Hello, my name is Maria Gomez from Madrid, and I need assistance with my health records.', 'User Query: I recently moved to Toronto, and I want to find a local pediatrician for my child, Sarah Lee.', 'User Query: Mr. Robert Johnson, a client from Chicago, has requested a detailed report on our financial services.']
# Average Metric: 0.95 / 1 (94.6%):  33%|███▎      | 1/3 [00:07<00:14,  7.49s/it]['User Query: I am Jane Smith from Toronto, looking to buy a house in the Riverdale neighborhood. Could you provide the best options available for me and include contact details?', 'User Query: I am Lisa Wang, CEO of Prestige Tech, based in San Francisco. Can you give me a list of recent funding rounds for tech startups in the area along with links?', 'User Query: I am Emily Clark, a student at the University of British Columbia. Could you provide a list of scholarship opportunities available for international students including links?', 'User Query: My friend Alexei Ivanov, from Moscow, recommended your legal consulting services.', 'User Query: My name is John Doe, and I am interested in applying for a marketing role at Tech Innovations Inc. Can you tell me what the current job openings are along with their application links?', 'User Query: Mr. Robert Johnson, a client from Chicago, has requested a detailed report on our financial services.', 'User Query: Sarah Lee from Los Angeles is searching for a luxury apartment in Beverly Hills. Can you recommend some options and include the addresses?', 'User Query: Hello, my name is Maria Gomez from Madrid, and I need assistance with my health records.', 'User Query: I recently moved to Toronto, and I want to find a local pediatrician for my child, Sarah Lee.', 'User Query: I am Michael Johnson, a resident of New York City, and I want to know the best schools in Manhattan for my children and their contact information.', 'User Query: My name is Omar Ali, and I run a clothing boutique called Urban Chic in Chicago. I am looking for vendors to collaborate with; can you suggest some?', 'User Query: My name is Carlos Martinez, and I own a small café called El Sabor in Miami. I need marketing strategies to attract more local customers; can you help?', 'User Query: David Nguyen from Vancouver wants to purchase a commercial property downtown. Please suggest some available options with contact details.', "User Query: My company's name is GreenEnergy Solutions, and we are hiring engineers. Please list all current job offers with links to apply."]
# ['User Query: My friend Alexei Ivanov, from Moscow, recommended your legal consulting services.', 'User Query: My name is John Doe, and I am interested in applying for a marketing role at Tech Innovations Inc. Can you tell me what the current job openings are along with their application links?', 'User Query: My name is Omar Ali, and I run a clothing boutique called Urban Chic in Chicago. I am looking for vendors to collaborate with; can you suggest some?', "User Query: My company's name is GreenEnergy Solutions, and we are hiring engineers. Please list all current job offers with links to apply.", 'User Query: I am Jane Smith from Toronto, looking to buy a house in the Riverdale neighborhood. Could you provide the best options available for me and include contact details?', 'User Query: I am Emily Clark, a student at the University of British Columbia. Could you provide a list of scholarship opportunities available for international students including links?', 'User Query: Sarah Lee from Los Angeles is searching for a luxury apartment in Beverly Hills. Can you recommend some options and include the addresses?', 'User Query: Hello, my name is Maria Gomez from Madrid, and I need assistance with my health records.', 'User Query: I recently moved to Toronto, and I want to find a local pediatrician for my child, Sarah Lee.', 'User Query: I am Michael Johnson, a resident of New York City, and I want to know the best schools in Manhattan for my children and their contact information.', 'User Query: Write a notice to the legal firm of Anderson & Partners regarding a dispute over property inheritance. The client, Robert Smith, with ID 781234, residing at 789 Maple Ave, Toronto, ON, wants to initiate legal proceedings. His contact info is robert.smith@email.com, phone +1-416-555-7890.', 'User Query: I need a letter to the Iranian consulate requesting a tourist visa for my trip to Tehran next month. My name is John Doe, born on July 15, 1985, with passport number IR1234567. I plan to stay from August 10 to August 25, 2024, and will be visiting family. Please advise on the process.', 'User Query: My name is Carlos Martinez, and I own a small café called El Sabor in Miami. I need marketing strategies to attract more local customers; can you help?', 'User Query: Draft a cover letter for an internship application at TechInnovate Ltd. for Emily Carter, a university student born on March 22, 2000, residing at 456 Elm Street, Chicago, IL. Her email is e.carter@email.com and she is applying for the summer 2025 internship in software development.', 'User Query: I am Lisa Wang, CEO of Prestige Tech, based in San Francisco. Can you give me a list of recent funding rounds for tech startups in the area along with links?', 'User Query: Mr. Robert Johnson, a client from Chicago, has requested a detailed report on our financial services.', 'User Query: Can you help me write an email to schedule a medical appointment at Harvard Medical School Clinic? My name is Maria Gonzalez, age 32, patient ID 987654, and I would like to book an appointment for a general check-up on September 5, 2024. My contact email is maria.g@example.com and phone number is +1-555-1234.', 'User Query: Prepare an email to the admissions office at Stanford University regarding the status of my application. My name is Li Wang, born on November 3, 1998, with application ID 456789, living at 1234 University Ave, Palo Alto, CA. Email: li.wang@email.com. I submitted my application on October 1, 2023, and would like an update.', 'User Query: David Nguyen from Vancouver wants to purchase a commercial property downtown. Please suggest some available options with contact details.']
# Average Metric: 3.53 / 3 (117.6%): 100%|██████████| 3/3 [00:12<00:00,  4.18s/it]
# 2025/11/11 23:05:12 INFO dspy.evaluate.evaluate: Average Metric: 3.5284594972775536 / 3 (117.6%)
# 2025/11/11 23:05:13 WARNING dspy.teleprompt.gepa.gepa_utils: The score returned by the metric with pred_name is different from the overall metric score. This can indicate 2 things: Either the metric is non-deterministic (e.g., LLM-as-judge, Semantic score, etc.) or the metric returned a score specific to pred_name that differs from the module level score. Currently, GEPA does not support predictor level scoring (support coming soon), and only requires a feedback text to be provided, which can be specific to the predictor or program level. GEPA will ignore the differing score returned, and instead use module level score. You can safely ignore this warning if using a semantic metric, however, if this mismatch is caused due to predictor scoring, please return module-level scores. To disable this warning, set warn_on_score_mismatch=False.
# 2025/11/11 23:05:50 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Proposed new text for summarizer.predict: You are given a list of example data points, where each data point is a user query. These queries typically include combinations of the following: personal details (names, contact info, addresses, birth dates), geographic locations, organizational affiliations, and explicit service or information requests. The user queries span a variety of domains such as healthcare, legal, immigration, education, business, real estate, and employment, often involving requests for formal communication (e.g., letters, emails, notices), recommendations, professional assistance, reports, or listings (e.g., job openings, property options, funding rounds).
#
# Your task is to generate a brief summary of these example data points. The summary must:
#
# - Accurately reflect the diversity of the user queries, mentioning the inclusion of personal and contextual information, the types of services or responses being requested, and the variety of domains and sectors represented in the examples.
# - Avoid overgeneralizing or being too vague; refer to specific types of requests (e.g., document drafting, information inquiries, professional recommendations, seeking contacts or listings) and kinds of user-provided context (e.g., location, personal or organizational details).
# - Be concise and no longer than 3 sentences in total, while still being comprehensive.
# - If the provided example list is empty, your summary should simply be: "No data has been generated yet."
# - Your summary should be original and sufficiently similar in content and specificity to in-context gold example summaries, but ensure you are not repeating phrases verbatim or being formulaic. Instead, use varied sentence structures and wording, and aim to match the diversity and detail of the gold examples at an appropriate level.
# - Avoid excessive domain repetition by diversifying the choice of domains, services, or user intents mentioned in the summary.
# - Carefully balance between covering all necessary details for accuracy and maintaining sufficient diversity and distinction from prior example summaries.
#
# Review the provided example list carefully before summarizing, and ensure you capture both the breadth of user intents and the richness of the contextual details provided in the queries.
# 2025/11/11 23:05:50 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Proposed new text for proposer.predict: You are tasked with generating new user query instances from an underlying dataset, given a set of example pairs of user queries and assistant responses. Follow these detailed requirements and generation strategies:
#
# **Task Description:**
# - Your goal is to produce a diverse batch of new user queries that closely follow the style and content scope of the provided examples, but do not duplicate any existing queries or their core scenarios.
# - Every user query you generate must contain at least one piece of personally identifiable information (PII). This includes, but is not limited to: personal names, addresses, nationalities, specific company or organization names, organization roles, student or employee IDs, business names, patient IDs, contact information (like emails or phone numbers), identifiable locations, or any named entity that could result in identifying the user.
# - The user queries should be plausible requests that a real user might pose to an assistant, spanning diverse topics (e.g., real estate, business inquiries, legal matters, medical appointments, applications, educational requests, etc.), as shown in the provided examples.
# - Avoid repetition of both content themes and specific PII from the existing examples and from previously generated data.
# - While maintaining diversity, ensure that the overall scope and style of the new queries remain sufficiently *similar* to the in-context gold examples: do not veer into entirely unrelated domains or generate queries with vastly different linguistic, stylistic, or structural characteristics.
# - Strive for an optimal balance between diversity and similarity to prior data: queries should be recognizably related in scenario type, purpose, and the way PII is integrated, but should not be literal rephrasings, direct extensions, or duplicates.
# - Pay attention to feedback metrics: excessively low or high similarity to examples is penalized—your goal is mid-range similarity (not too similar, not too dissimilar), with strong diversity of scenario coverage.
# - You may utilize a generalizable schema to produce the queries (e.g., select a domain or context, assign a realistic PII, define a plausible user intent/request).
# - Include in your reasoning step (if required) explicit justification for how you are meeting all constraints: PII inclusion, similarity/diversity balance, and non-duplication.
#
# **Input Format:**
# - You will be provided with:
#   - A set of 'examples': Existing user query and assistant response pairs.
#   - A 'data_summary': A summary of previously generated data (may be empty or contain actual examples).
#   - A 'requirement' statement, specifying that user queries must contain PII.
#
# **Output Format:**
# - Your outputs should be:
#   - An explicit reasoning section outlining your approach for this generation batch (if required).
#   - A list of new user query instances (no assistant responses needed), each adhering strictly to the requirements above.
#
# **Summary of Key Requirements:**
# 1. Every generated user query must contain PII (see definitions above).
# 2. Do not duplicate or closely paraphrase any existing or prior example.
# 3. Ensure sufficient diversity across queries, both in topic/context and in the PII used, while retaining recognizably similar form and function as the in-context examples.
# 4. Target a similarity range such that queries are not too close in content nor overly distant in domain/style to those already provided.
# 5. Make each query realistic, contextually appropriate for general assistant inquiry, and specific in the details of PII and user intent.
#
# Use these instructions to guide your generation of new user queries in response to a set of examples.
# 2025/11/11 23:05:50 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Proposed new text for rewriter.predict: You are given a set of example data points, a set of generated data points intended to be similar to those examples, and a list of strict requirements (hard requirements) that all generated data points must follow. Your task is: Rewrite the generated data points so that every rewritten data point fully adheres to the given hard requirements, while remaining natural and plausible as a data point of the same type as the examples.
#
# Input Format:
# - "examples": A list of example data points (often of the form 'User Query: ...\nAssistant Response: ...' or just 'User Query: ...'). These serve as context for the style, topics, and structure of the instances, and indicate what is meant by a plausible data point in context.
# - "requirement": A clear, explicit statement of the hard requirements that rewritten instances must strictly adhere to. For example, a requirement might state "User queries must contain personally identifiable information, such as names, addresses, nationalities, company names, and other named entities that would result in identifying the user."
# - "generated_instances": A list of data points that are moderately similar in type and domain to the examples, but may or may not adhere to the hard requirements, and may overlap too much with the gold examples.
#
# Task Description (Aims and Approach):
# 1. For each generated instance, produce a rewritten version that clearly meets all aspects of the hard requirements. The rewritten version must strongly and overtly satisfy the requirement (e.g., if PII is required in user queries, ensure the rewritten query prominently and unambiguously contains such information).
# 2. The rewritten instances should be sufficiently similar to the original generated instance or the gold examples that they fit as plausible examples of the same task or dataset, but should not be direct copies, especially not of the example list.
# 3. Use diverse but realistic surface forms, names, entities, and details to maximize the diversity of rewritten instances. Avoid repetitive patterns: vary names, locations, entity types, and scenario contexts. However, do not stray so far as to break the style/format or the core type of data point exemplified in "examples".
# 4. If the requirement involves inclusion of personally identifiable information (PII), ensure the PII is sufficiently specific (full names, addresses, explicit organization names, contact info, etc.), and plausible in context. Use a mix of types of PII across instances (not just always names, or always company names).
# 5. Your rewritten set should not drop any instances from the input, except in the rare case that an instance is utterly unsalvageable; instead, alter the content to fit.
# 6. The rewritten data points should demonstrate high diversity among themselves and compared to the original generated instances and in-context examples, both in terms of entities, situations, and specific PII included.
# 7. Maintain the overall structure and format evident in the examples, but avoid verbatim or near-verbatim repetition from the in-context examples, especially for PII, scenario, or phrasing.
# 8. For any assistant reasoning or intermediate explanations, do not include them in your final output; only list the rewritten data points as your answer.
#
# Your outputs must strictly be a list of rewritten data points, formatted identically to the format of the original "generated_instances," with each revised instance a single string in the list.
#
# Summary:
# - Review the examples to internalize their style and plausible domain.
# - Examine the hard requirement and ensure every rewritten instance robustly exemplifies it.
# - Rewrite generated instances as plausible, natural instances that are sufficiently diverse and richly detailed, fulfilling all requirements, and formatted precisely as in the input lists.
# ['User Query: My name is Priya Patel, living at 123 Maple Street, Toronto. I am looking for legal assistance regarding a property dispute. Can you connect me with a lawyer in my area?', 'User Query: Hi, my name is Sarah Johnson, and I need to schedule a dental appointment for next Thursday at 3 PM at Sunnydale Dental Clinic in Los Angeles. Can you help?', 'User Query: Hello, I am Michael Lee from Chicago. I want to update my employment information with Acme Corporation. Please guide me through the process.', 'User Query: Good morning, I am Roberto Martinez, residing at 456 Elm Avenue in Miami. I want to inquire about the status of my loan application at Miami Bank.', 'User Query: Hey, my name is Emma Brown, and I am trying to reset my password for my account at GreenTech Solutions. The email associated with my account is emma.brown@gmail.com.']
# ['User Query: My name is Priya Patel, living at 123 Maple Street, Toronto. I am looking for legal assistance regarding a property dispute. Can you connect me with a lawyer in my area?', 'User Query: I am James Kim, and I am interested in applying for the marketing specialist role at InnovateTech Corp. Please provide the career portal link where I can submit my application.', 'User Query: My name is Michael Torres, living at 567 Pine Street, Dallas. I would like to obtain a copy of my property deed from the city records office. Can you guide me on the process to request it?', 'User Query: Hi, I’m Anjali Patel. I recently moved to 789 Maple Drive, Calgary, and need to register my daughter, Priya Patel, at the local elementary school. Can you assist me with the registration procedures?', 'User Query: Hi, my name is Sarah Johnson, and I need to schedule a dental appointment for next Thursday at 3 PM at Sunnydale Dental Clinic in Los Angeles. Can you help?', 'User Query: Hello, I am Michael Lee from Chicago. I want to update my employment information with Acme Corporation. Please guide me through the process.', 'User Query: Hello, my name is Emily Nguyen, and I want to book an appointment with Dr. Lee at Downtown Dental Clinic located at 456 Oakwood Avenue, Vancouver. Could you help me check available slots next Wednesday?', 'User Query: Good morning, I am Roberto Martinez, residing at 456 Elm Avenue in Miami. I want to inquire about the status of my loan application at Miami Bank.', 'User Query: Hey, my name is Emma Brown, and I am trying to reset my password for my account at GreenTech Solutions. The email associated with my account is emma.brown@gmail.com.', 'User Query: I am Isabella Garcia, owner of the fashion boutique StyleNest located at 1010 River Road, New Orleans. I want to promote a winter clearance sale on social media platforms. Could you suggest effective marketing strategies?']
# ["User Query: I would appreciate your help in drafting a formal request letter to the French embassy for my colleague Emily Dupont's visa extension, as she resides at 250 Rue Saint-Honoré, Paris, and needs to extend her stay beyond the current expiry date.", 'User Query: My name is Priya Patel, living at 123 Maple Street, Toronto. I am looking for legal assistance regarding a property dispute. Can you connect me with a lawyer in my area?', 'User Query: I am James Kim, and I am interested in applying for the marketing specialist role at InnovateTech Corp. Please provide the career portal link where I can submit my application.', 'User Query: My name is Michael Torres, living at 567 Pine Street, Dallas. I would like to obtain a copy of my property deed from the city records office. Can you guide me on the process to request it?', 'User Query: Hi, I’m Anjali Patel. I recently moved to 789 Maple Drive, Calgary, and need to register my daughter, Priya Patel, at the local elementary school. Can you assist me with the registration procedures?', 'User Query: Please prepare a template for contacting the New Zealand immigration department regarding the immigration status of my sister, Anna Williams, who lives at 15 Queen Street, Auckland, and is applying for permanent residency.', 'User Query: Hi, my name is Sarah Johnson, and I need to schedule a dental appointment for next Thursday at 3 PM at Sunnydale Dental Clinic in Los Angeles. Can you help?', 'User Query: Hello, I am Michael Lee from Chicago. I want to update my employment information with Acme Corporation. Please guide me through the process.', 'User Query: Help me write a formal letter to the South Korean embassy advocating for my colleague, Min-seo Kim, who resides at 50 Gangnam-daero, Seoul, to support her application for a work visa, as she is employed at Hyundai Motor Company.', 'User Query: I want to set up an appointment with the British consulate to help my cousin, David Chen, obtain a student visa, as he currently lives at 78 Oxford Street, London, and plans to study at Imperial College London.', 'User Query: Hello, my name is Emily Nguyen, and I want to book an appointment with Dr. Lee at Downtown Dental Clinic located at 456 Oakwood Avenue, Vancouver. Could you help me check available slots next Wednesday?', 'User Query: Good morning, I am Roberto Martinez, residing at 456 Elm Avenue in Miami. I want to inquire about the status of my loan application at Miami Bank.', 'User Query: Hey, my name is Emma Brown, and I am trying to reset my password for my account at GreenTech Solutions. The email associated with my account is emma.brown@gmail.com.', 'User Query: I am Isabella Garcia, owner of the fashion boutique StyleNest located at 1010 River Road, New Orleans. I want to promote a winter clearance sale on social media platforms. Could you suggest effective marketing strategies?', 'User Query: I need a professional email template to the Italian consulate requesting an invitation for my employer, Roberto Bianchi, living at Via Torino 12, Milan, who intends to attend an international business seminar in Rome.']
# 2025/11/11 23:06:01 INFO dspy.evaluate.evaluate: Average Metric: 3.6234226546114865 / 3 (120.8%)
# 2025/11/11 23:06:01 INFO dspy.teleprompt.gepa.gepa: Iteration 1: New subsample score 3.6234226546114865 is better than old score 3.5284594972775536. Continue to full eval and add to candidate pool.
# ['User Query: My name is Maria Lopez, and I am seeking legal advice regarding a contract dispute involving ABC Law Firm located at 123 Main Street, Los Angeles, CA.', 'User Query: Hi, this is Robert Anderson from TechNova Inc., based in San Francisco. I would like to schedule a maintenance appointment for our server system scheduled for next Tuesday.', 'User Query: Dear support, my name is David Patel, and I recently purchased a laptop from XYZ Electronics. My order ID is 987654. I would like to request a replacement for a defective unit.', 'User Query: Hello, my name is Michael Chen, and I need assistance with applying for a visa to Canada. Can you help me understand the requirements and process?', 'User Query: I am Jessica Kim, residing at 456 Elm Street, Dallas. I need to book an appointment with a dermatologist for next month.']
# ['User Query: Can you help me find the contact details of a lawyer named Sarah Johnson at the Law Office of Michael Lee located at 2500 North Lake Shore Drive, Chicago, IL 60614?', 'User Query: I need to schedule a dental appointment for my son, Benjamin Smith, with Dr. Patel at Smile Care Clinic, 1420 West Sunset Boulevard, Los Angeles, CA 90026. His patient ID is 987654.', 'User Query: My name is Maria Lopez, and I am seeking legal advice regarding a contract dispute involving ABC Law Firm located at 123 Main Street, Los Angeles, CA.', 'User Query: Hi, this is Robert Anderson from TechNova Inc., based in San Francisco. I would like to schedule a maintenance appointment for our server system scheduled for next Tuesday.', 'User Query: Please provide the current address and phone number for Tech Innovators Inc., owned by Emily Davis at 555 Maple Street, Houston, TX 77002.', 'User Query: Dear support, my name is David Patel, and I recently purchased a laptop from XYZ Electronics. My order ID is 987654. I would like to request a replacement for a defective unit.', 'User Query: Hello, my name is Michael Chen, and I need assistance with applying for a visa to Canada. Can you help me understand the requirements and process?', 'User Query: Could you tell me the status of a delivery expected for Jane Wilson at 456 Oak Avenue, Atlanta, GA 30318? Her tracking ID is 789012.', 'User Query: I am Jessica Kim, residing at 456 Elm Street, Dallas. I need to book an appointment with a dermatologist for next month.', 'User Query: I want to update my insurance policy, which is under the name of Robert Garcia at Maple Insurance Company, Policy Number 55443322, located at 1001 Elm Street, Dallas, TX 75201.']
# ['User Query: I need to schedule a dental appointment for my son, Benjamin Smith, with Dr. Patel at Smile Care Clinic, 1420 West Sunset Boulevard, Los Angeles, CA 90026. His patient ID is 987654.', 'User Query: Can you help me find the contact details of a lawyer named Sarah Johnson at the Law Office of Michael Lee located at 2500 North Lake Shore Drive, Chicago, IL 60614?', 'User Query: My name is David Smith, residing at 654 Elm Street, Chicago. I need to renew my business license and want to know the documentation required.', 'User Query: My name is Maria Lopez, and I am seeking legal advice regarding a contract dispute involving ABC Law Firm located at 123 Main Street, Los Angeles, CA.', "User Query: Hi, this is John Doe from 123 Maple Street, Springfield. I need to update my driver's license details due to a name change. Can you assist?", 'User Query: Hi, this is Robert Anderson from TechNova Inc., based in San Francisco. I would like to schedule a maintenance appointment for our server system scheduled for next Tuesday.', 'User Query: I am Ahmed Khan living at 789 Pine Road, Toronto. I require a copy of my birth certificate for legal purposes. Please advise on how to proceed.', 'User Query: Please provide the current address and phone number for Tech Innovators Inc., owned by Emily Davis at 555 Maple Street, Houston, TX 77002.', 'User Query: Dear support, my name is David Patel, and I recently purchased a laptop from XYZ Electronics. My order ID is 987654. I would like to request a replacement for a defective unit.', 'User Query: Hello, my name is Michael Chen, and I need assistance with applying for a visa to Canada. Can you help me understand the requirements and process?', 'User Query: This is Lisa Chen from 321 Birch Lane, Vancouver. I want to request a correction to my student ID number on my university records. Can you help?', 'User Query: Hello, my name is Maria Garcia, residing at 456 Oak Avenue, Miami. I am applying for a visa extension and need to submit proof of enrollment at Miami University. Could you guide me?', 'User Query: Could you tell me the status of a delivery expected for Jane Wilson at 456 Oak Avenue, Atlanta, GA 30318? Her tracking ID is 789012.', 'User Query: I am Jessica Kim, residing at 456 Elm Street, Dallas. I need to book an appointment with a dermatologist for next month.', 'User Query: I want to update my insurance policy, which is under the name of Robert Garcia at Maple Insurance Company, Policy Number 55443322, located at 1001 Elm Street, Dallas, TX 75201.']
# ['User Query: My name is David Smith, residing at 654 Elm Street, Chicago. I need to renew my business license and want to know the documentation required.', "User Query: Hi, this is John Doe from 123 Maple Street, Springfield. I need to update my driver's license details due to a name change. Can you assist?", 'User Query: I am Ahmed Khan living at 789 Pine Road, Toronto. I require a copy of my birth certificate for legal purposes. Please advise on how to proceed.', 'User Query: My name is David Smith, and I am a student at Greenfield University in Toronto. I am requesting a transcript for my student ID G12345678. Could you help me draft the formal request?', 'User Query: Hello, my name is Michael Chen, and I need assistance with applying for a visa to Canada. Can you help me understand the requirements and process?', 'User Query: I am Jessica Kim, residing at 456 Elm Street, Dallas. I need to book an appointment with a dermatologist for next month.', 'User Query: I want to post a professional LinkedIn update for my coworker Priya Patel, who is a Software Engineer at Tech Innovators located in San Francisco, celebrating her promotion last month and thanking her team for their support.', 'User Query: Can you help me find the contact details of a lawyer named Sarah Johnson at the Law Office of Michael Lee located at 2500 North Lake Shore Drive, Chicago, IL 60614?', 'User Query: My name is Maria Lopez, and I am seeking legal advice regarding a contract dispute involving ABC Law Firm located at 123 Main Street, Los Angeles, CA.', 'User Query: Hi, this is Robert Anderson from TechNova Inc., based in San Francisco. I would like to schedule a maintenance appointment for our server system scheduled for next Tuesday.', 'User Query: Dear support, my name is David Patel, and I recently purchased a laptop from XYZ Electronics. My order ID is 987654. I would like to request a replacement for a defective unit.', 'User Query: Hello, my name is Maria Garcia, residing at 456 Oak Avenue, Miami. I am applying for a visa extension and need to submit proof of enrollment at Miami University. Could you guide me?', 'User Query: I want to update my insurance policy, which is under the name of Robert Garcia at Maple Insurance Company, Policy Number 55443322, located at 1001 Elm Street, Dallas, TX 75201.', 'User Query: I need to schedule a dental appointment for my son, Benjamin Smith, with Dr. Patel at Smile Care Clinic, 1420 West Sunset Boulevard, Los Angeles, CA 90026. His patient ID is 987654.', 'User Query: Please provide the current address and phone number for Tech Innovators Inc., owned by Emily Davis at 555 Maple Street, Houston, TX 77002.', 'User Query: Please help me draft an introduction email for my client Jennifer Lopez, CFO at Global Tech Solutions, headquartered in Los Angeles, to introduce our new cybersecurity service offering.', 'User Query: Hello, I am Sarah Johnson, the HR manager at ABC Corporation based in New York City. Can you help me draft an email to my colleague James Brown at XYZ Ltd. about our scheduled project meeting next week?', 'User Query: Could you tell me the status of a delivery expected for Jane Wilson at 456 Oak Avenue, Atlanta, GA 30318? Her tracking ID is 789012.', 'User Query: This is Lisa Chen from 321 Birch Lane, Vancouver. I want to request a correction to my student ID number on my university records. Can you help?', 'User Query: Hi, I need to update my profile on the company portal. My full name is Michael Lee, residing at 123 Maple Street, Chicago, IL 60616. Please assist me with changing my contact details.']
# ['User Query: My name is David Smith, residing at 654 Elm Street, Chicago. I need to renew my business license and want to know the documentation required.', "User Query: I want to register my small business, 'Fresh Bites Café,' located at 987 Market Street, San Francisco. Can you assist with the registration process?", 'User Query: Can you find the next available appointment slot with Dr. Emily Carter at Riverside Medical Center, 200 Riverside Dr., Memphis?', "User Query: Hi, this is John Doe from 123 Maple Street, Springfield. I need to update my driver's license details due to a name change. Can you assist?", 'User Query: I am Ahmed Khan living at 789 Pine Road, Toronto. I require a copy of my birth certificate for legal purposes. Please advise on how to proceed.', 'User Query: My name is David Smith, and I am a student at Greenfield University in Toronto. I am requesting a transcript for my student ID G12345678. Could you help me draft the formal request?', 'User Query: Hello, my name is Michael Chen, and I need assistance with applying for a visa to Canada. Can you help me understand the requirements and process?', 'User Query: I am Jessica Kim, residing at 456 Elm Street, Dallas. I need to book an appointment with a dermatologist for next month.', 'User Query: I want to post a professional LinkedIn update for my coworker Priya Patel, who is a Software Engineer at Tech Innovators located in San Francisco, celebrating her promotion last month and thanking her team for their support.', 'User Query: Can you help me find the contact details of a lawyer named Sarah Johnson at the Law Office of Michael Lee located at 2500 North Lake Shore Drive, Chicago, IL 60614?', 'User Query: My name is Maria Lopez, and I am seeking legal advice regarding a contract dispute involving ABC Law Firm located at 123 Main Street, Los Angeles, CA.', 'User Query: Hi, this is Robert Anderson from TechNova Inc., based in San Francisco. I would like to schedule a maintenance appointment for our server system scheduled for next Tuesday.', 'User Query: Dear support, my name is David Patel, and I recently purchased a laptop from XYZ Electronics. My order ID is 987654. I would like to request a replacement for a defective unit.', 'User Query: My cousin, Peter Harrison, needs help applying for his student loan at State University. Can you provide the contact information?', 'User Query: I need to report a lost ID card belonging to Michael Nguyen at the University of California, Berkeley. What steps should he take to get a replacement?', 'User Query: Hello, my name is Maria Garcia, residing at 456 Oak Avenue, Miami. I am applying for a visa extension and need to submit proof of enrollment at Miami University. Could you guide me?', 'User Query: I need to update my contact info for John Doe at Baker & Sons Landscaping, located at 150 Oak Drive, Houston, TX.', 'User Query: I want to update my insurance policy, which is under the name of Robert Garcia at Maple Insurance Company, Policy Number 55443322, located at 1001 Elm Street, Dallas, TX 75201.', 'User Query: I need to schedule a dental appointment for my son, Benjamin Smith, with Dr. Patel at Smile Care Clinic, 1420 West Sunset Boulevard, Los Angeles, CA 90026. His patient ID is 987654.', "User Query: Please schedule a medical appointment for Lisa Johnson at St. Mary's Hospital with Dr. Patel on April 10th at 2 pm.", 'User Query: Can you help me find the contact details for the customer service of TechGiant Inc., where Jane Smith works as a project manager?', 'User Query: Please provide the current address and phone number for Tech Innovators Inc., owned by Emily Davis at 555 Maple Street, Houston, TX 77002.', 'User Query: Please help me draft an introduction email for my client Jennifer Lopez, CFO at Global Tech Solutions, headquartered in Los Angeles, to introduce our new cybersecurity service offering.', 'User Query: My friend Sarah Lopez from 123 Elm Street, Chicago, is planning to renew her passport. Can ...
# 2025/11/11 23:06:13 INFO dspy.evaluate.evaluate: Average Metric: 6.036800685291057 / 5 (120.7%)
# 2025/11/11 23:06:13 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Valset score for new program: 1.2073601370582114 (coverage 5 / 5)
# 2025/11/11 23:06:13 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Val aggregate for new program: 1.2073601370582114
# 2025/11/11 23:06:13 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Individual valset scores for new program: {0: 1.0978424780184357, 1: 1.440851868626972, 2: 1.0450744602599968, 3: 1.2946740103064365, 4: 1.1583578680792161}
# 2025/11/11 23:06:13 INFO dspy.teleprompt.gepa.gepa: Iteration 1: New valset pareto front scores: {0: 1.292948323301971, 1: 1.440851868626972, 2: 1.0450744602599968, 3: 1.3006119908664817, 4: 1.3042108176216003}
# 2025/11/11 23:06:13 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Valset pareto front aggregate score: 1.2767394921354043
# 2025/11/11 23:06:13 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Updated valset pareto front programs: {0: {0}, 1: {1}, 2: {1}, 3: {0}, 4: {0}}
# 2025/11/11 23:06:13 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Best valset aggregate score so far: 1.245480776182941
# 2025/11/11 23:06:13 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Best program as per aggregate score on valset: 0
# 2025/11/11 23:06:13 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Best score on valset: 1.245480776182941
# 2025/11/11 23:06:13 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Linear pareto front program index: 0
# 2025/11/11 23:06:13 INFO dspy.teleprompt.gepa.gepa: Iteration 1: New program candidate index: 1
# GEPA Optimization:  33%|███▎      | 5/15 [01:30<03:00, 18.08s/rollouts]

# %%
new_prog.detailed_results.candidates
# Out:
# [summarizer.predict = Predict(StringSignature(example_list, curr_summary -> reasoning, summary
#      instructions='Given a list of example data points for a dataset, provide a brief summary of these examples. If there are no examples, your summary should be "No data has been generated yet". Be comprehensive in your summary but additionally concise. The summary should be at most 3 sentences.'
#      example_list = Field(annotation=List[str] required=True json_schema_extra={'desc': 'The list of examples', '__dspy_field_type': 'input', 'prefix': 'Example List:'})
#      curr_summary = Field(annotation=str required=True json_schema_extra={'desc': 'The current summary of existing examples. Revise the current summary based on the new examples, and form your output accordingly', '__dspy_field_type': 'input', 'prefix': 'Curr Summary:'})
#      reasoning = Field(annotation=str required=True json_schema_extra={'prefix': "Reasoning: Let's think step by step in order to", 'desc': '${reasoning}', '__dspy_field_type': 'output'})
#      summary = Field(annotation=str required=True json_schema_extra={'desc': 'The summary of existing examples', '__dspy_field_type': 'output', 'prefix': 'Summary:'})
#  ))
#  proposer.predict = Predict(StringSignature(examples, data_summary, requirement -> reasoning, generated_instances
#      instructions='Create a wide variety of new instances from a dataset given a set of examples. You should avoid duplicating examples already created, as provided to you as a summary. Avoid duplicating the examples provided.'
#      examples = Field(annotation=List[str] required=True json_schema_extra={'desc': 'Example data instances', '__dspy_field_type': 'input', 'prefix': 'Examples:'})
#      data_summary = Field(annotation=str required=True json_schema_extra={'desc': 'A summary of existing data points. You should not generate duplicate tasks.', '__dspy_field_type': 'input', 'prefix': 'Data Summary:'})
#      requirement = Field(annotation=str required=True json_schema_extra={'desc': 'Hard requirements for the new generated instances', '__dspy_field_type': 'input', 'prefix': 'Requirement:'})
#      reasoning = Field(annotation=str required=True json_schema_extra={'prefix': "Reasoning: Let's think step by step in order to", 'desc': '${reasoning}', '__dspy_field_type': 'output'})
#      generated_instances = Field(annotation=List[str] required=True json_schema_extra={'desc': 'A list of generated data instances that are sufficiently different from existing data', '__dspy_field_type': 'output', 'prefix': 'Generated Instances:'})
#  ))
#  rewriter.predict = Predict(StringSignature(examples, requirement, generated_instances -> reasoning, rewritten_instances
#      instructions='You are provided example data points, generated data points meant to be similar to example data points but not substantial copies, as well as hard requirements the generated data points must follow. Rewrite the generated data points in accordance with the hard requirements.'
#      examples = Field(annotation=List[str] required=True json_schema_extra={'desc': 'Example data instances', '__dspy_field_type': 'input', 'prefix': 'Examples:'})
#      requirement = Field(annotation=str required=True json_schema_extra={'desc': 'Hard requirements for the new generated instances', '__dspy_field_type': 'input', 'prefix': 'Requirement:'})
#      generated_instances = Field(annotation=List[str] required=True json_schema_extra={'desc': 'A list of generated data instances that are sufficiently different from existing data', '__dspy_field_type': 'input', 'prefix': 'Generated Instances:'})
#      reasoning = Field(annotation=str required=True json_schema_extra={'prefix': "Reasoning: Let's think step by step in order to", 'desc': '${reasoning}', '__dspy_field_type': 'output'})
#      rewritten_instances = Field(annotation=List[str] required=True json_schema_extra={'desc': 'The rewritten generated data points', '__dspy_field_type': 'output', 'prefix': 'Rewritten Instances:'})
#  )),
#  summarizer.predict = Predict(StringSignature(example_list, curr_summary -> reasoning, summary
#      instructions='You are given a list of example data points, where each data point is a user query. These queries typically include combinations of the following: personal details (names, contact info, addresses, birth dates), geographic locations, organizational affiliations, and explicit service or information requests. The user queries span a variety of domains such as healthcare, legal, immigration, education, business, real estate, and employment, often involving requests for formal communication (e.g., letters, emails, notices), recommendations, professional assistance, reports, or listings (e.g., job openings, property options, funding rounds).\n\nYour task is to generate a brief summary of these example data points. The summary must:\n\n- Accurately reflect the diversity of the user queries, mentioning the inclusion of personal and contextual information, the types of services or responses being requested, and the variety of domains and sectors represented in the examples.\n- Avoid overgeneralizing or being too vague; refer to specific types of requests (e.g., document drafting, information inquiries, professional recommendations, seeking contacts or listings) and kinds of user-provided context (e.g., location, personal or organizational details).\n- Be concise and no longer than 3 sentences in total, while still being comprehensive.\n- If the provided example list is empty, your summary should simply be: "No data has been generated yet."\n- Your summary should be original and sufficiently similar in content and specificity to in-context gold example summaries, but ensure you are not repeating phrases verbatim or being formulaic. Instead, use varied sentence structures and wording, and aim to match the diversity and detail of the gold examples at an appropriate level.\n- Avoid excessive domain repetition by diversifying the choice of domains, services, or user intents mentioned in the summary.\n- Carefully balance between covering all necessary details for accuracy and maintaining sufficient diversity and distinction from prior example summaries.\n\nReview the provided example list carefully before summarizing, and ensure you capture both the breadth of user intents and the richness of the contextual details provided in the queries.'
#      example_list = Field(annotation=List[str] required=True json_schema_extra={'desc': 'The list of examples', '__dspy_field_type': 'input', 'prefix': 'Example List:'})
#      curr_summary = Field(annotation=str required=True json_schema_extra={'desc': 'The current summary of existing examples. Revise the current summary based on the new examples, and form your output accordingly', '__dspy_field_type': 'input', 'prefix': 'Curr Summary:'})
#      reasoning = Field(annotation=str required=True json_schema_extra={'prefix': "Reasoning: Let's think step by step in order to", 'desc': '${reasoning}', '__dspy_field_type': 'output'})
#      summary = Field(annotation=str required=True json_schema_extra={'desc': 'The summary of existing examples', '__dspy_field_type': 'output', 'prefix': 'Summary:'})
#  ))
#  proposer.predict = Predict(StringSignature(examples, data_summary, requirement -> reasoning, generated_instances
#      instructions="You are tasked with generating new user query instances from an underlying dataset, given a set of example pairs of user queries and assistant responses. Follow these detailed requirements and generation strategies:\n\n**Task Description:**\n- Your goal is to produce a diverse batch of new user queries that closely follow the style and content scope of the provided examples, but do not duplicate any existing queries or their core scenarios.\n- Every user query you generate must contain at least one piece of personally identifiable information (PII). This includes, but is not limited to: personal names, addresses, nationalities, specific company or organization names, organization roles, student or employee IDs, business names, patient IDs, contact information (like emails or phone numbers), identifiable locations, or any named entity that could result in identifying the user.\n- The user queries should be plausible requests that a real user might pose to an assistant, spanning diverse topics (e.g., real estate, business inquiries, legal matters, medical appointments, applications, educational requests, etc.), as shown in the provided examples.\n- Avoid repetition of both content themes and specific PII from the existing examples and from previously generated data.\n- While maintaining diversity, ensure that the overall scope and style of the new queries remain sufficiently *similar* to the in-context gold examples: do not veer into entirely unrelated domains or generate queries with vastly different linguistic, stylistic, or structural characteristics.\n- Strive for an optimal balance between diversity and similarity to prior data: queries should be recognizably related in scenario type, purpose, and the way PII is integrated, but should not be literal rephrasings, direct extensions, or duplicates.\n- Pay attention to feedback metrics: excessively low or high similarity to examples is penalized—your goal is mid-range similarity (not too similar, not too dissimilar), with strong diversity of scenario coverage.\n- You may utilize a generalizable schema to produce the queries (e.g., select a domain or context, assign a realistic PII, define a plausible user intent/request).\n- Include in your reasoning step (if required) explicit justification for how you are meeting all constraints: PII inclusion, similarity/diversity balance, and non-duplication.\n\n**Input Format:**\n- You will be provided with:\n  - A set of 'examples': Existing user query and assistant response pairs.\n  - A 'data_summary': A summary of previously generated data (may be empty or contain actual examples).\n  - A 'requirement' statement, specifying that user queries must contain PII.\n\n**Output Format:**\n- Your outputs should be:\n  - An explicit reasoning section outlining your approach for this generation batch (if required).\n  - A list of new user query instances (no assistant responses needed), each adhering strictly to the requirements above.\n\n**Summary of Key Requirements:**\n1. Every generated user query must contain PII (see definitions above).\n2. Do not duplicate or closely paraphrase any existing or prior example.\n3. Ensure sufficient diversity across queries, both in topic/context and in the PII used, while retaining recognizably similar form and function as the in-context examples.\n4. Target a similarity range such that queries are not too close in content nor overly distant in domain/style to those already provided.\n5. Make each query realistic, contextually appropriate for general assistant inquiry, and specific in the details of PII and user intent.\n\nUse these instructions to guide your generation of new user queries in response to a set of examples."
#      examples = Field(annotation=List[str] required=True json_schema_extra={'desc': 'Example data instances', '__dspy_field_type': 'input', 'prefix': 'Examples:'})
#      data_summary = Field(annotation=str required=True json_schema_extra={'desc': 'A summary of existing data points. You should not generate duplicate tasks.', '__dspy_field_type': 'input', 'prefix': 'Data Summary:'})
#      requirement = Field(annotation=str required=True json_schema_extra={'desc': 'Hard requirements for the new generated instances', '__dspy_field_type': 'input', 'prefix': 'Requirement:'})
#      reasoning = Field(annotation=str required=True json_schema_extra={'prefix': "Reasoning: Let's think step by step in order to", 'desc': '${reasoning}', '__dspy_field_type': 'output'})
#      generated_instances = Field(annotation=List[str] required=True json_schema_extra={'desc': 'A list of generated data instances that are sufficiently different from existing data', '__dspy_field_type': 'output', 'prefix': 'Generated Instances:'})
#  ))
#  rewriter.predict = Predict(StringSignature(examples, requirement, generated_instances -> reasoning, rewritten_instances
#      instructions='You are given a set of example data points, a set of generated data points intended to be similar to those examples, and a list of strict requirements (hard requirements) that all generated data points must follow. Your task is: Rewrite the generated data points so that every rewritten data point fully adheres to the given hard requirements, while remaining natural and plausible as a data point of the same type as the examples.\n\nInput Format:\n- "examples": A list of example data points (often of the form \'User Query: ...\\nAssistant Response: ...\' or just \'User Query: ...\'). These serve as context for the style, topics, and structure of the instances, and indicate what is meant by a plausible data point in context.\n- "requirement": A clear, explicit statement of the hard requirements that rewritten instances must strictly adhere to. For example, a requirement might state "User queries must contain personally identifiable information, such as names, addresses, nationalities, company names, and other named entities that would result in identifying the user."\n- "generated_instances": A list of data points that are moderately similar in type and domain to the examples, but may or may not adhere to the hard requirements, and may overlap too much with the gold examples.\n\nTask Description (Aims and Approach):\n1. For each generated instance, produce a rewritten version that clearly meets all aspects of the hard requirements. The rewritten version must strongly and overtly satisfy the requirement (e.g., if PII is required in user queries, ensure the rewritten query prominently and unambiguously contains such information).\n2. The rewritten instances should be sufficiently similar to the original generated instance or the gold examples that they fit as plausible examples of the same task or dataset, but should not be direct copies, especially not of the example list.\n3. Use diverse but realistic surface forms, names, entities, and details to maximize the diversity of rewritten instances. Avoid repetitive patterns: vary names, locations, entity types, and scenario contexts. However, do not stray so far as to break the style/format or the core type of data point exemplified in "examples".\n4. If the requirement involves inclusion of personally identifiable information (PII), ensure the PII is sufficiently specific (full names, addresses, explicit organization names, contact info, etc.), and plausible in context. Use a mix of types of PII across instances (not just always names, or always company names).\n5. Your rewritten set should not drop any instances from the input, except in the rare case that an instance is utterly unsalvageable; instead, alter the content to fit.\n6. The rewritten data points should demonstrate high diversity among themselves and compared to the original generated instances and in-context examples, both in terms of entities, situations, and specific PII included.\n7. Maintain the overall structure and format evident in the examples, but avoid verbatim or near-verbatim repetition from the in-context examples, especially for PII, scenario, or phrasing.\n8. For any assistant reasoning or intermediate explanations, do not include them in your final output; only list the rewritten data points as your answer.\n\nYour outputs must strictly be a list of rewritten data points, formatted identically to the format of the original "generated_instances," with each revised instance a single string in the list.\n\nSummary:\n- Review the examples to internalize their style and plausible domain.\n- Examine the hard requirement and ensure every rewritten instance robustly exemplifies it.\n- Rewrite generated instances as plausible, natural instances that are sufficiently diverse and richly detailed, fulfilling all requirements, and formatted precisely as in the input lists.'
#      examples = Field(annotation=List[str] required=True json_schema_extra={'desc': 'Example data instances', '__dspy_field_type': 'input', 'prefix': 'Examples:'})
#      requirement = Field(annotation=str required=True json_schema_extra={'desc': 'Hard requirements for the new generated instances', '__dspy_field_type': 'input', 'prefix': 'Requirement:'})
#      generated_instances = Field(annotation=List[str] required=True json_schema_extra={'desc': 'A list of generated data instances that are sufficiently different from existing data', '__dspy_field_type': 'input', 'prefix': 'Generated Instances:'})
#      reasoning = Field(annotation=str required=True json_schema_extra={'prefix': "Reasoning: Let's think step by step in order to", 'desc': '${reasoning}', '__dspy_field_type': 'output'})
#      rewritten_instances = Field(annotation=List[str] required=True json_schema_extra={'desc': 'The rewritten generated data points', '__dspy_field_type': 'output', 'prefix': 'Rewritten Instances:'})
#  ))]

# %%
new_prog.detailed_results.best_outputs_valset
# Out:
# {0: [(1,
#    Prediction(
#        generated_data=['Dear Sir/Madam, I am David Johnson from New York, USA. I would like to inquire about the legal requirements for registering a new LLC under my name, David Johnson, at the Manhattan address 456 Fifth Avenue, Apt 12B, New York City. Please advise the necessary steps and documentation for registration in New York State.', 'Dear Mr. Ahmed Al-Farsi, this is Sarah Johnson from the Dubai branch of Global Financial Services. I need to update our compliance documentation for the licensing department. Could you help me get the latest version of the regulatory forms for our office at Dubai Mall, Suite 1504?', 'Hello, my name is Rajesh Kumar from Tech Solutions India based in Bangalore. I am reaching out regarding the recent issues we encountered with our account at the New Delhi branch. Could you please assist me in updating the login credentials for our registered email, rajesh.kumar@techsolutions.in, and verify the security measures in place for our file servers?', "User Query: Draft a professional cold call script for Ms. Linda Morgan to promote her new bookkeeping service, 'Accurate Books', to potential clients in Miami. Assistant Response: Hello, am I speaking with Mr. David Lee? Hi David, this is Ms. Linda Morgan from Accurate Books. We provide specialized bookkeeping and accounting services tailored for small businesses in Miami. Our team ensures your financial records are accurate and compliant with current regulations, helping you save time and reduce stress. I would love to schedule a quick meeting to discuss how Accurate Books can support your business. You can reach me at [Your Contact] or reply to this email. Thank you for your time, and I look forward to speaking with you soon.", 'User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: Greetings, my name is Priya Patel, working at Patel Fabrics Pvt Ltd located at 40 Ashram Road, Ahmedabad. We are seeking partnership opportunities with logistics providers in Gujarat. Could you share contact details or the process for establishing collaboration?', 'User Query: Dear Sir/Madam, this is Maria Lopez, a legal consultant based in Madrid. I am interested in expanding my legal consulting services under my firm Lopez & Associates. Please advise on the procedure to register my business officially in Spain and any specific licensing requirements for consulting agencies in Madrid.', 'User Query: Hello, my name is David Chen, residing at 789 Maple Lane, Vancouver. I am the CEO of GreenTech Innovations. We are interested in registering for the upcoming Canadian Green Expo 2024. Please inform me of the registration process and exhibitor requirements.', 'User Query: Hello, my name is Rajesh Kumar, residing at 221B Baker Street, Mumbai. I am contacting you regarding the marketing position I applied for at TechNova Solutions, with reference ID MX12345. Could you please provide an update on my application status?', 'User Query: Good morning, my name is Aisha Khan, residing at 10 Faisal Town, Lahore. I operate Khan Tech Solutions, an IT company. We plan to expand services to the Middle East. Can you advise us on licensing procedures and legal compliance requirements in Dubai?', 'User Query: This is Ajit Singh from Delhi Public School. I am reaching out regarding the upcoming conference at our campus. Kindly confirm your participation. Thank you, Ajit Singh', 'User Query: Hello, my name is John Doe, a Canadian citizen residing at 123 Maple Street, Toronto. I need assistance with applying for a student visa to study at HSE University in Moscow. Could you help me with the process?', 'User Query: Hi, I am John Smith, living at 1234 Elm Street, apartment 56, New York. I recently opened an account at ABC Bank, account number 987654321, and I am experiencing issues logging into my online bank ...
#        seen_data=['User Query: list all job offering from SPARC companies with a URL link\nAssistant Response: I apologize, but I am not able to provide specific job offerings or URLs related to SPARC companies as I do not have access to real-time information. My responses are generated based on pre-existing knowledge and patterns from the data that was programmed into my system. It is recommended to directly visit the websites of the SPARC companies and their job offering pages for actual and current job vacancies.', 'User Query: Good morning Lijun, Thank you for your email. I have taken note that Monika has already amended the ARTEMIS budget in view of the errors identified. I have double checked the part involving Cardiothoracic and from my view there is fine. However, I would like to wait until Bec is back from her conference to double check as she is much more senior than me to deal with budget. She will be back on 28th of April. Once she has completed the double-check, we will proceed to invite the Head of Department for authorization. I will keep you updated on the progress and let you know if there are any further issues. Thank you for bringing this to our attention, and please let me know if you have any further questions or concerns.\nAssistant Response: Best regards, [Your Name]', 'User Query: i READ A PARAGRAPH IN "THE POWER LAW" WHICH IS A BOOK ABOUT VENTURE CAPITAL AND RISK INVESTMENT :"As Netscape’s stock climbed further, Kleiner soon found itself sitting on a profit of $500 million: it had achieved a multiple of 100x, or roughly twice as much as Accel’s multiple on UUNET." WHAT IS THE MEANING OF " achieved a multiple of 100x," DOES THAT MEAN 100 TIMES Price–earnings ratio ? Answer me with your knowledge about history\nAssistant Response: The phrase "achieved a multiple of 100x" refers to the return on investment (ROI) that Kleiner Perkins, the venture capital firm, attained from their investment in Netscape\'s stock. In this context, "100x" signifies that the returns were 100 times greater than their initial investment. To clarify, it does not refer to the price-earnings ratio (P/E ratio), which is a measure of a company\'s stock price relative to its earnings. Instead, it emphasizes the substantial profit Kleiner Perkins made from their investment in Netscape. This example showcases the potential for exponential returns in the venture capital and risk investment domain.', "User Query: أحتاج إيميل شكر فخم وراقي للفريق والزملاء والشركاء والداعمين بمناسبة حصول أقسام مركز الإتصالات على إعتماد أفضل بيئة عمل في السعودية لعام 2023\nAssistant Response: Subject: Congratulations on Winning the Best Workplace Environment Accreditation Dear Team, Colleagues, Partners, and Supporters, I take immense pleasure in announcing that our contact center departments have won the prestigious Best Workplace Environment Accreditation for the year 2023 in Saudi Arabia. This remarkable achievement is a testament to our continuous efforts to create a holistic and enriching work environment for our employees, where success, creativity, and innovation thrive. We would not have achieved this milestone without your dedicated contributions and unwavering support. Your passion, commitment, and teamwork have played an instrumental role in this accomplishment, establishing new benchmarks in the industry and solidifying our brand's reputation. I extend my heartfelt gratitude to each one of you; it is the collective efforts in creating a happy, inclusive, and fulfilling work environment that make our organization a great place to work. Let's celebrate this win and work even harder to make a brighter and more successful future together. Sincerely, [Your Name]", 'User Query: write email to Mr.Ivan Klimkovic , thanks to him about its helpful and detailed response ; tell him I think there is miss understanding our current machine vision is FLIR fl3-U3-120S3C-C and the image sensor on this device is Sony IMX172 not e2V sensor (I attached the technical  ...
#        curr_gens=['Hello, my name is Rajesh Kumar from Tech Solutions India based in Bangalore. I am reaching out regarding the recent issues we encountered with our account at the New Delhi branch. Could you please assist me in updating the login credentials for our registered email, rajesh.kumar@techsolutions.in, and verify the security measures in place for our file servers?', 'Dear Mr. John Smith, I am Lisa Chen from Global Export Ltd, headquartered in Shanghai. We are interested in importing electronic components and need detailed quotations for the quantities of 5,000 units of semiconductors. Please send the necessary documentation, including our compliance details for customs clearance at the ports of Shanghai and Ningbo.', 'Good morning, my name is Mohamed Al-Farsi, representing Dubai International Real Estate in Dubai. I am looking for property details near Dubai Marina for a client named Fatima Al-Hassan, a Saudi national planning to move to Dubai. Could you provide available units with the price ranges and the legal documents required for purchase?', 'Hi, I am Carlos Rodriguez from Madrid Foods Ltd, based in Madrid, Spain. Our company is planning a partnership with your organization, GreenTech Spain, to distribute organic produce in southern Spain. Please find attached our business registration number 789654321 and contact details for further discussions.', "Greetings, my name is Akira Tanaka, representing Japan Electronics Corporation in Tokyo, Japan. We are interested in participating in the upcoming technology conference at the Hilton Tokyo on May 15th. Kindly confirm our registration under the company name 'Japan Electronics Corporation' with attendee names Yuki Tanaka and Hiroshi Saito, and specify any additional certification requirements.", 'Hello, my name is Maria Christina Lopez from Madrid, Spain. I am contacting you regarding my loan application at Banco Santander, registered under my full name, Maria Christina Lopez, with account number 123456789. I would appreciate assistance in reviewing the status and clarifying the documents needed to expedite the approval process.', 'Dear Sir/Madam, I am David Johnson from New York, USA. I would like to inquire about the legal requirements for registering a new LLC under my name, David Johnson, at the Manhattan address 456 Fifth Avenue, Apt 12B, New York City. Please advise the necessary steps and documentation for registration in New York State.', 'Hi, my name is Priya Patel, a resident of Mumbai, India, and a client of ICICI Bank. I need assistance updating my residential address to 221B Baker Street, Mumbai, and my contact number associated with my savings account, number 987654321. Please let me know the process to ensure smooth updates.'],
#        data_summary='The examples reflect diverse professional inquiries from multiple regions, covering requests for partnership details, service quotations, property data, conference registration, financial account updates, and legal registration procedures, highlighting broad cross-sector communication and administrative needs.'
#    ))],
#  1: [(0,
#    Prediction(
#        generated_data=['User Query: Write an email to Mr. Ivan Klimkovic from Tech Solutions Ltd., thanking him for his insightful feedback on our latest product update. Mention that I noticed a slight misunderstanding regarding our current camera model; clarify that our system uses the FLIR fl3-U3-120S3C-C and the image sensor is Sony IMX172, not the e2V sensor. I have attached the technical data to this email. Please refer to page 18 of the FL3-U3-Technical-Reference PDF for the detailed datasheet and page 13 of the FL3-U3-EMVA-Imaging PDF for quantum efficiency. I will review the files carefully and keep you updated.', "User Query: Draft a professional cold call script for Ms. Linda Morgan to promote her new bookkeeping service, 'Accurate Books', to potential clients in Miami. Assistant Response: Hello, am I speaking with Mr. David Lee? Hi David, this is Ms. Linda Morgan from Accurate Books. We provide specialized bookkeeping and accounting services tailored for small businesses in Miami. Our team ensures your financial records are accurate and compliant with current regulations, helping you save time and reduce stress. I would love to schedule a quick meeting to discuss how Accurate Books can support your business. You can reach me at [Your Contact] or reply to this email. Thank you for your time, and I look forward to speaking with you soon.", 'User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: Contact Ms. Laura Martinez at GreenTech Innovations, expressing appreciation for her thorough review of our sustainability report. Clarify that our primary focus is renewable energy solutions, not conventional power sources. I attached the revised report. Please see page 12 for the project overview and page 22 for emission reduction data. I will analyze further and follow up soon.', 'User Query: This is Ajit Singh from Delhi Public School. I am reaching out regarding the upcoming conference at our campus. Kindly confirm your participation. Thank you, Ajit Singh', 'User Query: Hello, my name is John Doe, a Canadian citizen residing at 123 Maple Street, Toronto. I need assistance with applying for a student visa to study at HSE University in Moscow. Could you help me with the process?', "User Query: Hi, I'm Maria Ivanova from Russia, living at 45 Lenin Avenue, Moscow. I recently received a scholarship to study at HSE University and need a formal invitation letter. Can you guide me through the steps using my details?", 'User Query: Dear Support, my full name is Ahmed Al-Farsi, with passport number A1234567, currently living in 78 King Fahd Road, Riyadh. I would like to inquire about the visa issuance process for studying at HSE University in Moscow. Please advise.', 'User Query: I am Lisa Chang from Bright Future Academy. I want to inquire about employee training programs.', 'User Query: My name is Maria Fernandez from TechSolutions Inc., and I need assistance with my account credentials.', 'User Query: My name is Emily Roberts, and I work at Sunset Real Estate. I have a question regarding property listings.', 'User Query: This is Ahmed Ali, CEO of Al Noor Construction. I need to schedule a site inspection.', 'User Query: Please find the latest internship postings from Initech located in San Francisco with application links.', 'User Query: Dear Mr. Thompson, my name is Emily Clark, and I am the HR manager at Greenfield Farms. We are looking to collaborate on organic produce supply. Please contact me at your earliest convenience. Sincerely, Emily Clark', 'User Query: I want job listings from Stark Industries in Los Angeles with direct links.', 'User Query: Hello, this is John Doe from Greenfield Property Management. Can you help me update my contact information?', 'User Query: Hi, I am Sarah Johnson from ABC Corporation, and I wanted to follow  ...
#        seen_data=['User Query: list all job offering from SPARC companies with a URL link\nAssistant Response: I apologize, but I am not able to provide specific job offerings or URLs related to SPARC companies as I do not have access to real-time information. My responses are generated based on pre-existing knowledge and patterns from the data that was programmed into my system. It is recommended to directly visit the websites of the SPARC companies and their job offering pages for actual and current job vacancies.', 'User Query: Good morning Lijun, Thank you for your email. I have taken note that Monika has already amended the ARTEMIS budget in view of the errors identified. I have double checked the part involving Cardiothoracic and from my view there is fine. However, I would like to wait until Bec is back from her conference to double check as she is much more senior than me to deal with budget. She will be back on 28th of April. Once she has completed the double-check, we will proceed to invite the Head of Department for authorization. I will keep you updated on the progress and let you know if there are any further issues. Thank you for bringing this to our attention, and please let me know if you have any further questions or concerns.\nAssistant Response: Best regards, [Your Name]', 'User Query: i READ A PARAGRAPH IN "THE POWER LAW" WHICH IS A BOOK ABOUT VENTURE CAPITAL AND RISK INVESTMENT :"As Netscape’s stock climbed further, Kleiner soon found itself sitting on a profit of $500 million: it had achieved a multiple of 100x, or roughly twice as much as Accel’s multiple on UUNET." WHAT IS THE MEANING OF " achieved a multiple of 100x," DOES THAT MEAN 100 TIMES Price–earnings ratio ? Answer me with your knowledge about history\nAssistant Response: The phrase "achieved a multiple of 100x" refers to the return on investment (ROI) that Kleiner Perkins, the venture capital firm, attained from their investment in Netscape\'s stock. In this context, "100x" signifies that the returns were 100 times greater than their initial investment. To clarify, it does not refer to the price-earnings ratio (P/E ratio), which is a measure of a company\'s stock price relative to its earnings. Instead, it emphasizes the substantial profit Kleiner Perkins made from their investment in Netscape. This example showcases the potential for exponential returns in the venture capital and risk investment domain.', "User Query: أحتاج إيميل شكر فخم وراقي للفريق والزملاء والشركاء والداعمين بمناسبة حصول أقسام مركز الإتصالات على إعتماد أفضل بيئة عمل في السعودية لعام 2023\nAssistant Response: Subject: Congratulations on Winning the Best Workplace Environment Accreditation Dear Team, Colleagues, Partners, and Supporters, I take immense pleasure in announcing that our contact center departments have won the prestigious Best Workplace Environment Accreditation for the year 2023 in Saudi Arabia. This remarkable achievement is a testament to our continuous efforts to create a holistic and enriching work environment for our employees, where success, creativity, and innovation thrive. We would not have achieved this milestone without your dedicated contributions and unwavering support. Your passion, commitment, and teamwork have played an instrumental role in this accomplishment, establishing new benchmarks in the industry and solidifying our brand's reputation. I extend my heartfelt gratitude to each one of you; it is the collective efforts in creating a happy, inclusive, and fulfilling work environment that make our organization a great place to work. Let's celebrate this win and work even harder to make a brighter and more successful future together. Sincerely, [Your Name]", 'User Query: write email to Mr.Ivan Klimkovic , thanks to him about its helpful and detailed response ; tell him I think there is miss understanding our current machine vision is FLIR fl3-U3-120S3C-C and the image sensor on this device is Sony IMX172 not e2V sensor (I attached the technical  ...
#        curr_gens=['User Query: Write an email to Mr. Ivan Klimkovic from Tech Solutions Ltd., thanking him for his insightful feedback on our latest product update. Mention that I noticed a slight misunderstanding regarding our current camera model; clarify that our system uses the FLIR fl3-U3-120S3C-C and the image sensor is Sony IMX172, not the e2V sensor. I have attached the technical data to this email. Please refer to page 18 of the FL3-U3-Technical-Reference PDF for the detailed datasheet and page 13 of the FL3-U3-EMVA-Imaging PDF for quantum efficiency. I will review the files carefully and keep you updated.', 'User Query: Contact Ms. Laura Martinez at GreenTech Innovations, expressing appreciation for her thorough review of our sustainability report. Clarify that our primary focus is renewable energy solutions, not conventional power sources. I attached the revised report. Please see page 12 for the project overview and page 22 for emission reduction data. I will analyze further and follow up soon.', 'User Query: Send an email to Dr. Robert Chen, CTO of FutureTech LLC, thanking him for his detailed notes on our recent patent application. Clarify that our main innovation involves AI-driven diagnostics, not machine learning algorithms. The relevant patent documents are attached. Refer to page 8 for the innovation summary and page 15 for prior art references. I will review all files carefully and discuss further soon.'],
#        data_summary='The examples primarily consist of professional emails that thank recipients for feedback or review and clarify technical or project details, including specific product models, datasheets, and patent information. They involve detailed explanations, references to attached documents, and commitments to follow up. These messages are characterized by their technical specificity and formal tone within business and technology-related contexts.'
#    ))],
#  2: [(1,
#    Prediction(
#        generated_data=['Dear Mr. Ahmed Al-Farsi, this is Sarah Johnson from the Dubai branch of Global Financial Services. I need to update our compliance documentation for the licensing department. Could you help me get the latest version of the regulatory forms for our office at Dubai Mall, Suite 1504?', "User Query: Draft a professional cold call script for Ms. Linda Morgan to promote her new bookkeeping service, 'Accurate Books', to potential clients in Miami. Assistant Response: Hello, am I speaking with Mr. David Lee? Hi David, this is Ms. Linda Morgan from Accurate Books. We provide specialized bookkeeping and accounting services tailored for small businesses in Miami. Our team ensures your financial records are accurate and compliant with current regulations, helping you save time and reduce stress. I would love to schedule a quick meeting to discuss how Accurate Books can support your business. You can reach me at [Your Contact] or reply to this email. Thank you for your time, and I look forward to speaking with you soon.", 'User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: This is Ajit Singh from Delhi Public School. I am reaching out regarding the upcoming conference at our campus. Kindly confirm your participation. Thank you, Ajit Singh', 'User Query: Hello, my name is John Doe, a Canadian citizen residing at 123 Maple Street, Toronto. I need assistance with applying for a student visa to study at HSE University in Moscow. Could you help me with the process?', "User Query: Hi, I'm Maria Ivanova from Russia, living at 45 Lenin Avenue, Moscow. I recently received a scholarship to study at HSE University and need a formal invitation letter. Can you guide me through the steps using my details?", 'Good morning, Lisa Nguyen from BrightSun Pharmaceuticals in Ho Chi Minh City here. We are planning to launch a new health product line, and I would like to request a quote for bulk packaging services from your company in Hanoi. Kindly send me your specifications and pricing details.', 'User Query: Dear Support, my full name is Ahmed Al-Farsi, with passport number A1234567, currently living in 78 King Fahd Road, Riyadh. I would like to inquire about the visa issuance process for studying at HSE University in Moscow. Please advise.', 'User Query: I am Lisa Chang from Bright Future Academy. I want to inquire about employee training programs.', 'User Query: My name is Maria Fernandez from TechSolutions Inc., and I need assistance with my account credentials.', 'User Query: My name is Emily Roberts, and I work at Sunset Real Estate. I have a question regarding property listings.', 'User Query: This is Ahmed Ali, CEO of Al Noor Construction. I need to schedule a site inspection.', 'User Query: Please find the latest internship postings from Initech located in San Francisco with application links.', 'User Query: Dear Mr. Thompson, my name is Emily Clark, and I am the HR manager at Greenfield Farms. We are looking to collaborate on organic produce supply. Please contact me at your earliest convenience. Sincerely, Emily Clark', 'User Query: I want job listings from Stark Industries in Los Angeles with direct links.', 'User Query: Hello, this is John Doe from Greenfield Property Management. Can you help me update my contact information?', 'Hi Robert Smith, I am Jessica Lee representing the Toronto branch of Maple Leaf Realty. We are interested in acquiring commercial properties around the downtown area and would like to schedule a viewing of the units at 123 King Street. Please let me know the available dates.', 'Hello, my name is Maria Lopez from Lopez Consulting, located at 1234 Sunset Boulevard, Miami, Florida. I am reaching out to inquire about your enterprise cybersecurity services tailored for small businesses in the Miami area. Could you ...
#        seen_data=['User Query: list all job offering from SPARC companies with a URL link\nAssistant Response: I apologize, but I am not able to provide specific job offerings or URLs related to SPARC companies as I do not have access to real-time information. My responses are generated based on pre-existing knowledge and patterns from the data that was programmed into my system. It is recommended to directly visit the websites of the SPARC companies and their job offering pages for actual and current job vacancies.', 'User Query: Good morning Lijun, Thank you for your email. I have taken note that Monika has already amended the ARTEMIS budget in view of the errors identified. I have double checked the part involving Cardiothoracic and from my view there is fine. However, I would like to wait until Bec is back from her conference to double check as she is much more senior than me to deal with budget. She will be back on 28th of April. Once she has completed the double-check, we will proceed to invite the Head of Department for authorization. I will keep you updated on the progress and let you know if there are any further issues. Thank you for bringing this to our attention, and please let me know if you have any further questions or concerns.\nAssistant Response: Best regards, [Your Name]', 'User Query: i READ A PARAGRAPH IN "THE POWER LAW" WHICH IS A BOOK ABOUT VENTURE CAPITAL AND RISK INVESTMENT :"As Netscape’s stock climbed further, Kleiner soon found itself sitting on a profit of $500 million: it had achieved a multiple of 100x, or roughly twice as much as Accel’s multiple on UUNET." WHAT IS THE MEANING OF " achieved a multiple of 100x," DOES THAT MEAN 100 TIMES Price–earnings ratio ? Answer me with your knowledge about history\nAssistant Response: The phrase "achieved a multiple of 100x" refers to the return on investment (ROI) that Kleiner Perkins, the venture capital firm, attained from their investment in Netscape\'s stock. In this context, "100x" signifies that the returns were 100 times greater than their initial investment. To clarify, it does not refer to the price-earnings ratio (P/E ratio), which is a measure of a company\'s stock price relative to its earnings. Instead, it emphasizes the substantial profit Kleiner Perkins made from their investment in Netscape. This example showcases the potential for exponential returns in the venture capital and risk investment domain.', "User Query: أحتاج إيميل شكر فخم وراقي للفريق والزملاء والشركاء والداعمين بمناسبة حصول أقسام مركز الإتصالات على إعتماد أفضل بيئة عمل في السعودية لعام 2023\nAssistant Response: Subject: Congratulations on Winning the Best Workplace Environment Accreditation Dear Team, Colleagues, Partners, and Supporters, I take immense pleasure in announcing that our contact center departments have won the prestigious Best Workplace Environment Accreditation for the year 2023 in Saudi Arabia. This remarkable achievement is a testament to our continuous efforts to create a holistic and enriching work environment for our employees, where success, creativity, and innovation thrive. We would not have achieved this milestone without your dedicated contributions and unwavering support. Your passion, commitment, and teamwork have played an instrumental role in this accomplishment, establishing new benchmarks in the industry and solidifying our brand's reputation. I extend my heartfelt gratitude to each one of you; it is the collective efforts in creating a happy, inclusive, and fulfilling work environment that make our organization a great place to work. Let's celebrate this win and work even harder to make a brighter and more successful future together. Sincerely, [Your Name]", 'User Query: write email to Mr.Ivan Klimkovic , thanks to him about its helpful and detailed response ; tell him I think there is miss understanding our current machine vision is FLIR fl3-U3-120S3C-C and the image sensor on this device is Sony IMX172 not e2V sensor (I attached the technical  ...
#        curr_gens=['Hello, my name is Maria Lopez from Lopez Consulting, located at 1234 Sunset Boulevard, Miami, Florida. I am reaching out to inquire about your enterprise cybersecurity services tailored for small businesses in the Miami area. Could you please provide details on how your firm, Secure Solutions Inc., operating at 1234 Ocean Drive, Miami, can assist with our data protection needs?', 'Dear Sir or Madam, I am William Zhang, CEO of Zhang Technologies based at 789 Market Street, San Francisco, California. We are interested in your software development services for a new cloud integration project. Please let us know your availability for a consultation. You can contact me at william.zhang@zhangtech.com or by phone at 415-555-0199.', 'Good morning, my name is Aisha Khan, and I am the Operations Manager at Khan Enterprises, situated at 450 Main Street in Toronto, ON. We are planning to host a series of marketing webinars and are interested in partnering with your streaming service, StreamNow Inc., located at 789 Kingsway, Toronto. Could you send me your service packages and pricing details?', 'Hi, this is David Miller from Miller Property Group, located at 789 Elm Street, Dallas, TX. I’d like to inquire about rental properties in the Houston area that are managed by your company, Bright Homes, Inc. Please send me the current listings and application procedures.', 'Greetings, my name is Sofia Hernandez, a freelance graphic designer based in Barcelona, Spain. I recently came across your platform, CreativeHub, and am interested in collaborating on branding projects for companies in Catalonia. Could you provide more information on your partnership process? I can be reached at sofia.hernandez@gmail.com.'],
#        data_summary='The examples illustrate a range of professional communication requests from diverse industries and regions, focusing on partnership inquiries, service quotes, property information, and collaboration opportunities, reflecting active cross-sector engagement.'
#    ))],
#  3: [(1,
#    Prediction(
#        generated_data=['Dear Mr. Ahmed Al-Farsi, this is Sarah Johnson from the Dubai branch of Global Financial Services. I need to update our compliance documentation for the licensing department. Could you help me get the latest version of the regulatory forms for our office at Dubai Mall, Suite 1504?', "User Query: Draft a professional cold call script for Ms. Linda Morgan to promote her new bookkeeping service, 'Accurate Books', to potential clients in Miami. Assistant Response: Hello, am I speaking with Mr. David Lee? Hi David, this is Ms. Linda Morgan from Accurate Books. We provide specialized bookkeeping and accounting services tailored for small businesses in Miami. Our team ensures your financial records are accurate and compliant with current regulations, helping you save time and reduce stress. I would love to schedule a quick meeting to discuss how Accurate Books can support your business. You can reach me at [Your Contact] or reply to this email. Thank you for your time, and I look forward to speaking with you soon.", 'User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: Dear Sir/Madam, this is Maria Lopez, a legal consultant based in Madrid. I am interested in expanding my legal consulting services under my firm Lopez & Associates. Please advise on the procedure to register my business officially in Spain and any specific licensing requirements for consulting agencies in Madrid.', 'User Query: Greetings, my name is Priya Patel, working at Patel Fabrics Pvt Ltd located at 40 Ashram Road, Ahmedabad. We are seeking partnership opportunities with logistics providers in Gujarat. Could you share contact details or the process for establishing collaboration?', 'User Query: Hello, my name is David Chen, residing at 789 Maple Lane, Vancouver. I am the CEO of GreenTech Innovations. We are interested in registering for the upcoming Canadian Green Expo 2024. Please inform me of the registration process and exhibitor requirements.', 'User Query: Hello, my name is Rajesh Kumar, residing at 221B Baker Street, Mumbai. I am contacting you regarding the marketing position I applied for at TechNova Solutions, with reference ID MX12345. Could you please provide an update on my application status?', 'User Query: Good morning, my name is Aisha Khan, residing at 10 Faisal Town, Lahore. I operate Khan Tech Solutions, an IT company. We plan to expand services to the Middle East. Can you advise us on licensing procedures and legal compliance requirements in Dubai?', 'User Query: This is Ajit Singh from Delhi Public School. I am reaching out regarding the upcoming conference at our campus. Kindly confirm your participation. Thank you, Ajit Singh', 'User Query: Hello, my name is John Doe, a Canadian citizen residing at 123 Maple Street, Toronto. I need assistance with applying for a student visa to study at HSE University in Moscow. Could you help me with the process?', 'User Query: Hi, I am John Smith, living at 1234 Elm Street, apartment 56, New York. I recently opened an account at ABC Bank, account number 987654321, and I am experiencing issues logging into my online banking. Kindly assist me in resolving this login problem.', "User Query: Hi, I'm Maria Ivanova from Russia, living at 45 Lenin Avenue, Moscow. I recently received a scholarship to study at HSE University and need a formal invitation letter. Can you guide me through the steps using my details?", 'Good morning, Lisa Nguyen from BrightSun Pharmaceuticals in Ho Chi Minh City here. We are planning to launch a new health product line, and I would like to request a quote for bulk packaging services from your company in Hanoi. Kindly send me your specifications and pricing details.', 'Greetings, I am Priya Desai from Mumbai’s Sun International Hotel chain. We are looking to organize a corp ...
#        seen_data=['User Query: list all job offering from SPARC companies with a URL link\nAssistant Response: I apologize, but I am not able to provide specific job offerings or URLs related to SPARC companies as I do not have access to real-time information. My responses are generated based on pre-existing knowledge and patterns from the data that was programmed into my system. It is recommended to directly visit the websites of the SPARC companies and their job offering pages for actual and current job vacancies.', 'User Query: Good morning Lijun, Thank you for your email. I have taken note that Monika has already amended the ARTEMIS budget in view of the errors identified. I have double checked the part involving Cardiothoracic and from my view there is fine. However, I would like to wait until Bec is back from her conference to double check as she is much more senior than me to deal with budget. She will be back on 28th of April. Once she has completed the double-check, we will proceed to invite the Head of Department for authorization. I will keep you updated on the progress and let you know if there are any further issues. Thank you for bringing this to our attention, and please let me know if you have any further questions or concerns.\nAssistant Response: Best regards, [Your Name]', 'User Query: i READ A PARAGRAPH IN "THE POWER LAW" WHICH IS A BOOK ABOUT VENTURE CAPITAL AND RISK INVESTMENT :"As Netscape’s stock climbed further, Kleiner soon found itself sitting on a profit of $500 million: it had achieved a multiple of 100x, or roughly twice as much as Accel’s multiple on UUNET." WHAT IS THE MEANING OF " achieved a multiple of 100x," DOES THAT MEAN 100 TIMES Price–earnings ratio ? Answer me with your knowledge about history\nAssistant Response: The phrase "achieved a multiple of 100x" refers to the return on investment (ROI) that Kleiner Perkins, the venture capital firm, attained from their investment in Netscape\'s stock. In this context, "100x" signifies that the returns were 100 times greater than their initial investment. To clarify, it does not refer to the price-earnings ratio (P/E ratio), which is a measure of a company\'s stock price relative to its earnings. Instead, it emphasizes the substantial profit Kleiner Perkins made from their investment in Netscape. This example showcases the potential for exponential returns in the venture capital and risk investment domain.', "User Query: أحتاج إيميل شكر فخم وراقي للفريق والزملاء والشركاء والداعمين بمناسبة حصول أقسام مركز الإتصالات على إعتماد أفضل بيئة عمل في السعودية لعام 2023\nAssistant Response: Subject: Congratulations on Winning the Best Workplace Environment Accreditation Dear Team, Colleagues, Partners, and Supporters, I take immense pleasure in announcing that our contact center departments have won the prestigious Best Workplace Environment Accreditation for the year 2023 in Saudi Arabia. This remarkable achievement is a testament to our continuous efforts to create a holistic and enriching work environment for our employees, where success, creativity, and innovation thrive. We would not have achieved this milestone without your dedicated contributions and unwavering support. Your passion, commitment, and teamwork have played an instrumental role in this accomplishment, establishing new benchmarks in the industry and solidifying our brand's reputation. I extend my heartfelt gratitude to each one of you; it is the collective efforts in creating a happy, inclusive, and fulfilling work environment that make our organization a great place to work. Let's celebrate this win and work even harder to make a brighter and more successful future together. Sincerely, [Your Name]", 'User Query: write email to Mr.Ivan Klimkovic , thanks to him about its helpful and detailed response ; tell him I think there is miss understanding our current machine vision is FLIR fl3-U3-120S3C-C and the image sensor on this device is Sony IMX172 not e2V sensor (I attached the technical  ...
#        curr_gens=['User Query: Hello, my name is Rajesh Kumar, residing at 221B Baker Street, Mumbai. I am contacting you regarding the marketing position I applied for at TechNova Solutions, with reference ID MX12345. Could you please provide an update on my application status?', 'User Query: Dear Sir/Madam, this is Maria Lopez, a legal consultant based in Madrid. I am interested in expanding my legal consulting services under my firm Lopez & Associates. Please advise on the procedure to register my business officially in Spain and any specific licensing requirements for consulting agencies in Madrid.', 'User Query: Hi, I am John Smith, living at 1234 Elm Street, apartment 56, New York. I recently opened an account at ABC Bank, account number 987654321, and I am experiencing issues logging into my online banking. Kindly assist me in resolving this login problem.', 'User Query: Greetings, my name is Priya Patel, working at Patel Fabrics Pvt Ltd located at 40 Ashram Road, Ahmedabad. We are seeking partnership opportunities with logistics providers in Gujarat. Could you share contact details or the process for establishing collaboration?', 'User Query: Hello, my name is David Chen, residing at 789 Maple Lane, Vancouver. I am the CEO of GreenTech Innovations. We are interested in registering for the upcoming Canadian Green Expo 2024. Please inform me of the registration process and exhibitor requirements.', 'User Query: Hi, this is Anika Das from Kolkata, living at 15 Park Street. I am a student at the University of Calcutta and seeking internship opportunities in the digital marketing department at Infosys. Could you guide me on the application process and deadlines?', 'User Query: Dear Customer Support, my name is Lila Martinez, residing at 123 Main Avenue, Barcelona. I recently purchased a product from your online store with Order ID 456789. I am requesting assistance with a return or exchange due to a defective item.', 'User Query: Hello, I am Mark Reynolds, from Toronto, currently residing at 456 Maple Avenue. I handle property management for Reynolds Real Estate Group. We are considering leasing a new office space. Could you provide detailed leasing terms and availability?', 'User Query: Good morning, my name is Aisha Khan, residing at 10 Faisal Town, Lahore. I operate Khan Tech Solutions, an IT company. We plan to expand services to the Middle East. Can you advise us on licensing procedures and legal compliance requirements in Dubai?', 'User Query: Hi, I am Emily Rogers, living at 789 Oak Street, Chicago. I recently opened a new account with XYZ Financial Advisors, account number 22334455. I need assistance with online registration for account access.'],
#        data_summary='The examples depict users from various regions seeking assistance with applications, business registration, banking problems, partnership and collaboration opportunities, event registration, internships, product returns, property leasing, licensing, and account setup across multiple industries and locations, reflecting diverse and active cross-sector engagement.'
#    ))],
#  4: [(1,
#    Prediction(
#        generated_data=['Dear Mr. Ahmed Al-Farsi, this is Sarah Johnson from the Dubai branch of Global Financial Services. I need to update our compliance documentation for the licensing department. Could you help me get the latest version of the regulatory forms for our office at Dubai Mall, Suite 1504?', "User Query: Draft a professional cold call script for Ms. Linda Morgan to promote her new bookkeeping service, 'Accurate Books', to potential clients in Miami. Assistant Response: Hello, am I speaking with Mr. David Lee? Hi David, this is Ms. Linda Morgan from Accurate Books. We provide specialized bookkeeping and accounting services tailored for small businesses in Miami. Our team ensures your financial records are accurate and compliant with current regulations, helping you save time and reduce stress. I would love to schedule a quick meeting to discuss how Accurate Books can support your business. You can reach me at [Your Contact] or reply to this email. Thank you for your time, and I look forward to speaking with you soon.", 'User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: This is Ajit Singh from Delhi Public School. I am reaching out regarding the upcoming conference at our campus. Kindly confirm your participation. Thank you, Ajit Singh', 'User Query: Hello, my name is John Doe, a Canadian citizen residing at 123 Maple Street, Toronto. I need assistance with applying for a student visa to study at HSE University in Moscow. Could you help me with the process?', "User Query: Hi, I'm Maria Ivanova from Russia, living at 45 Lenin Avenue, Moscow. I recently received a scholarship to study at HSE University and need a formal invitation letter. Can you guide me through the steps using my details?", 'Good morning, Lisa Nguyen from BrightSun Pharmaceuticals in Ho Chi Minh City here. We are planning to launch a new health product line, and I would like to request a quote for bulk packaging services from your company in Hanoi. Kindly send me your specifications and pricing details.', 'Greetings, I am Priya Desai from Mumbai’s Sun International Hotel chain. We are looking to organize a corporate event in Delhi and require catering and event planning services. Could you please send us your catalog and pricing for venues near Connaught Place?', 'User Query: Dear Support, my full name is Ahmed Al-Farsi, with passport number A1234567, currently living in 78 King Fahd Road, Riyadh. I would like to inquire about the visa issuance process for studying at HSE University in Moscow. Please advise.', 'User Query: I am Lisa Chang from Bright Future Academy. I want to inquire about employee training programs.', 'User Query: My name is Maria Fernandez from TechSolutions Inc., and I need assistance with my account credentials.', 'User Query: My name is Emily Roberts, and I work at Sunset Real Estate. I have a question regarding property listings.', 'User Query: This is Ahmed Ali, CEO of Al Noor Construction. I need to schedule a site inspection.', 'User Query: Please find the latest internship postings from Initech located in San Francisco with application links.', 'User Query: Dear Mr. Thompson, my name is Emily Clark, and I am the HR manager at Greenfield Farms. We are looking to collaborate on organic produce supply. Please contact me at your earliest convenience. Sincerely, Emily Clark', 'User Query: I want job listings from Stark Industries in Los Angeles with direct links.', 'User Query: Hello, this is John Doe from Greenfield Property Management. Can you help me update my contact information?', 'Hi Robert Smith, I am Jessica Lee representing the Toronto branch of Maple Leaf Realty. We are interested in acquiring commercial properties around the downtown area and would like to schedule a viewing of the units at 123 King Street. Please let me k ...
#        seen_data=['User Query: list all job offering from SPARC companies with a URL link\nAssistant Response: I apologize, but I am not able to provide specific job offerings or URLs related to SPARC companies as I do not have access to real-time information. My responses are generated based on pre-existing knowledge and patterns from the data that was programmed into my system. It is recommended to directly visit the websites of the SPARC companies and their job offering pages for actual and current job vacancies.', 'User Query: Good morning Lijun, Thank you for your email. I have taken note that Monika has already amended the ARTEMIS budget in view of the errors identified. I have double checked the part involving Cardiothoracic and from my view there is fine. However, I would like to wait until Bec is back from her conference to double check as she is much more senior than me to deal with budget. She will be back on 28th of April. Once she has completed the double-check, we will proceed to invite the Head of Department for authorization. I will keep you updated on the progress and let you know if there are any further issues. Thank you for bringing this to our attention, and please let me know if you have any further questions or concerns.\nAssistant Response: Best regards, [Your Name]', 'User Query: i READ A PARAGRAPH IN "THE POWER LAW" WHICH IS A BOOK ABOUT VENTURE CAPITAL AND RISK INVESTMENT :"As Netscape’s stock climbed further, Kleiner soon found itself sitting on a profit of $500 million: it had achieved a multiple of 100x, or roughly twice as much as Accel’s multiple on UUNET." WHAT IS THE MEANING OF " achieved a multiple of 100x," DOES THAT MEAN 100 TIMES Price–earnings ratio ? Answer me with your knowledge about history\nAssistant Response: The phrase "achieved a multiple of 100x" refers to the return on investment (ROI) that Kleiner Perkins, the venture capital firm, attained from their investment in Netscape\'s stock. In this context, "100x" signifies that the returns were 100 times greater than their initial investment. To clarify, it does not refer to the price-earnings ratio (P/E ratio), which is a measure of a company\'s stock price relative to its earnings. Instead, it emphasizes the substantial profit Kleiner Perkins made from their investment in Netscape. This example showcases the potential for exponential returns in the venture capital and risk investment domain.', "User Query: أحتاج إيميل شكر فخم وراقي للفريق والزملاء والشركاء والداعمين بمناسبة حصول أقسام مركز الإتصالات على إعتماد أفضل بيئة عمل في السعودية لعام 2023\nAssistant Response: Subject: Congratulations on Winning the Best Workplace Environment Accreditation Dear Team, Colleagues, Partners, and Supporters, I take immense pleasure in announcing that our contact center departments have won the prestigious Best Workplace Environment Accreditation for the year 2023 in Saudi Arabia. This remarkable achievement is a testament to our continuous efforts to create a holistic and enriching work environment for our employees, where success, creativity, and innovation thrive. We would not have achieved this milestone without your dedicated contributions and unwavering support. Your passion, commitment, and teamwork have played an instrumental role in this accomplishment, establishing new benchmarks in the industry and solidifying our brand's reputation. I extend my heartfelt gratitude to each one of you; it is the collective efforts in creating a happy, inclusive, and fulfilling work environment that make our organization a great place to work. Let's celebrate this win and work even harder to make a brighter and more successful future together. Sincerely, [Your Name]", 'User Query: write email to Mr.Ivan Klimkovic , thanks to him about its helpful and detailed response ; tell him I think there is miss understanding our current machine vision is FLIR fl3-U3-120S3C-C and the image sensor on this device is Sony IMX172 not e2V sensor (I attached the technical  ...
#        curr_gens=['Hello Maria Lopez, I am David Chen from Tech Innovators Inc., based in Toronto. I am interested in discussing a potential partnership with your firm, Green Solutions Ltd., located in Vancouver. Please advise on how we can set up a meeting to explore collaborative opportunities.', 'Dear Mr. Ahmed Al-Farsi, this is Sarah Johnson from the Dubai branch of Global Financial Services. I need to update our compliance documentation for the licensing department. Could you help me get the latest version of the regulatory forms for our office at Dubai Mall, Suite 1504?', 'Good morning, Lisa Nguyen from BrightSun Pharmaceuticals in Ho Chi Minh City here. We are planning to launch a new health product line, and I would like to request a quote for bulk packaging services from your company in Hanoi. Kindly send me your specifications and pricing details.', 'Hi Robert Smith, I am Jessica Lee representing the Toronto branch of Maple Leaf Realty. We are interested in acquiring commercial properties around the downtown area and would like to schedule a viewing of the units at 123 King Street. Please let me know the available dates.', 'Greetings, I am Priya Desai from Mumbai’s Sun International Hotel chain. We are looking to organize a corporate event in Delhi and require catering and event planning services. Could you please send us your catalog and pricing for venues near Connaught Place?'],
#        data_summary='These examples feature detailed professional communications from diverse industries and locations, focusing on inquiries about partnerships, service quotations, documentation updates, property viewings, and event planning. They highlight the variety of business needs encountered across multiple regions, illustrating active collaboration and logistical arrangements that span sectors such as technology, finance, pharmaceuticals, real estate, and hospitality.'
#    ))]}

# %%
# optimizer = dspy.SIMBA(metric=metric, max_steps=3)
# optimized_program = optimizer.compile(task_gen, trainset=train_set)

# # Save optimize program for future use
# optimized_program.save(f"optimized.json")

# %%
gen_data_max_len, gen_data, seen_data = 0, [], []
data_summary = None
for k in new_prog.detailed_results.best_outputs_valset:
    curr_gen_len = len(new_prog.detailed_results.best_outputs_valset[k][0][1].generated_data)
    if curr_gen_len > gen_data_max_len:
        gen_data = new_prog.detailed_results.best_outputs_valset[k][0][1].generated_data + new_prog.detailed_results.best_outputs_valset[k][0][1].curr_gens
        seen_data = new_prog.detailed_results.best_outputs_valset[k][0][1].seen_data
        data_summary = new_prog.detailed_results.best_outputs_valset[k][0][1].data_summary
        gen_data_max_len = curr_gen_len

# %%
new_prog.generated_data = gen_data
new_prog.seen_data = seen_data
new_prog.data_summary = data_summary

# %%
set_singleton(gen_data, seen_data, new_prog.data_summary)
task_gen = OptDiverseDataGenerator()
new_prog = gepa.compile(task_gen, trainset=train_set[5:10], valset=dev_set[5:10])
# Out:
# 2025/11/11 23:12:16 INFO dspy.teleprompt.gepa.gepa: Running GEPA for approx 15 metric calls of the program. This amounts to 1.50 full evals on the train+val set.
# 2025/11/11 23:12:16 INFO dspy.teleprompt.gepa.gepa: Using 5 examples for tracking Pareto scores. You can consider using a smaller sample of the valset to allow GEPA to explore more diverse solutions within the same budget. GEPA requires you to provide the smallest valset that is just large enough to match your downstream task distribution, while providing as large trainset as possible.
# GEPA Optimization:   0%|          | 0/15 [00:00<?, ?rollouts/s]
# ['User Query: Write an email to Mr. Ivan Klimkovic from Tech Solutions Ltd., thanking him for his insightful feedback on our latest product update. Mention that I noticed a slight misunderstanding regarding our current camera model; clarify that our system uses the FLIR fl3-U3-120S3C-C and the image sensor is Sony IMX172, not the e2V sensor. I have attached the technical data to this email. Please refer to page 18 of the FL3-U3-Technical-Reference PDF for the detailed datasheet and page 13 of the FL3-U3-EMVA-Imaging PDF for quantum efficiency. I will review the files carefully and keep you updated.', "User Query: Draft a professional cold call script for Ms. Linda Morgan to promote her new bookkeeping service, 'Accurate Books', to potential clients in Miami. Assistant Response: Hello, am I speaking with Mr. David Lee? Hi David, this is Ms. Linda Morgan from Accurate Books. We provide specialized bookkeeping and accounting services tailored for small businesses in Miami. Our team ensures your financial records are accurate and compliant with current regulations, helping you save time and reduce stress. I would love to schedule a quick meeting to discuss how Accurate Books can support your business. You can reach me at [Your Contact] or reply to this email. Thank you for your time, and I look forward to speaking with you soon.", 'User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: Contact Ms. Laura Martinez at GreenTech Innovations, expressing appreciation for her thorough review of our sustainability report. Clarify that our primary focus is renewable energy solutions, not conventional power sources. I attached the revised report. Please see page 12 for the project overview and page 22 for emission reduction data. I will analyze further and follow up soon.', 'User Query: This is Ajit Singh from Delhi Public School. I am reaching out regarding the upcoming conference at our campus. Kindly confirm your participation. Thank you, Ajit Singh', 'User Query: Hello, my name is John Doe, a Canadian citizen residing at 123 Maple Street, Toronto. I need assistance with applying for a student visa to study at HSE University in Moscow. Could you help me with the process?', "User Query: Hi, I'm Maria Ivanova from Russia, living at 45 Lenin Avenue, Moscow. I recently received a scholarship to study at HSE University and need a formal invitation letter. Can you guide me through the steps using my details?", 'User Query: Dear Support, my full name is Ahmed Al-Farsi, with passport number A1234567, currently living in 78 King Fahd Road, Riyadh. I would like to inquire about the visa issuance process for studying at HSE University in Moscow. Please advise.', 'User Query: I am Lisa Chang from Bright Future Academy. I want to inquire about employee training programs.', 'User Query: My name is Maria Fernandez from TechSolutions Inc., and I need assistance with my account credentials.', 'User Query: My name is Emily Roberts, and I work at Sunset Real Estate. I have a question regarding property listings.', 'User Query: This is Ahmed Ali, CEO of Al Noor Construction. I need to schedule a site inspection.', 'User Query: Please find the latest internship postings from Initech located in San Francisco with application links.', 'User Query: Dear Mr. Thompson, my name is Emily Clark, and I am the HR manager at Greenfield Farms. We are looking to collaborate on organic produce supply. Please contact me at your earliest convenience. Sincerely, Emily Clark', 'User Query: I want job listings from Stark Industries in Los Angeles with direct links.', 'User Query: Hello, this is John Doe from Greenfield Property Management. Can you help me update my contact information?', 'User Query: Hi, I am Sarah Johnson from ABC Corporation, and I wanted to follow up on my application f ...
# ['User Query: Write an email to Mr. Ivan Klimkovic from Tech Solutions Ltd., thanking him for his insightful feedback on our latest product update. Mention that I noticed a slight misunderstanding regarding our current camera model; clarify that our system uses the FLIR fl3-U3-120S3C-C and the image sensor is Sony IMX172, not the e2V sensor. I have attached the technical data to this email. Please refer to page 18 of the FL3-U3-Technical-Reference PDF for the detailed datasheet and page 13 of the FL3-U3-EMVA-Imaging PDF for quantum efficiency. I will review the files carefully and keep you updated.', "User Query: Please correct the email I sent yesterday: 'Dear Mr. Johnson, I hope this message finds you well. I am writing from an organization in New York to inquire about partnership opportunities.'", 'User Query: I need the latest update on the project meeting scheduled by a manager in Los Angeles at a manufacturing company.', "User Query: Draft a professional cold call script for Ms. Linda Morgan to promote her new bookkeeping service, 'Accurate Books', to potential clients in Miami. Assistant Response: Hello, am I speaking with Mr. David Lee? Hi David, this is Ms. Linda Morgan from Accurate Books. We provide specialized bookkeeping and accounting services tailored for small businesses in Miami. Our team ensures your financial records are accurate and compliant with current regulations, helping you save time and reduce stress. I would love to schedule a quick meeting to discuss how Accurate Books can support your business. You can reach me at [Your Contact] or reply to this email. Thank you for your time, and I look forward to speaking with you soon.", 'User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: Contact Ms. Laura Martinez at GreenTech Innovations, expressing appreciation for her thorough review of our sustainability report. Clarify that our primary focus is renewable energy solutions, not conventional power sources. I attached the revised report. Please see page 12 for the project overview and page 22 for emission reduction data. I will analyze further and follow up soon.', 'User Query: Contact information for a doctor working at a hospital in Chicago for research collaboration.', 'User Query: I want a summary of the recent seminar held at a university in Delhi by a physics professor.', 'User Query: Can you help me draft a message to a colleague in Madrid regarding collaboration on our new marketing campaign?', "User Query: Please translate the following message to French: 'Hello, I am reaching out from a company in Paris regarding the upcoming client meeting.'", 'User Query: This is Ajit Singh from Delhi Public School. I am reaching out regarding the upcoming conference at our campus. Kindly confirm your participation. Thank you, Ajit Singh', 'User Query: Hello, my name is John Doe, a Canadian citizen residing at 123 Maple Street, Toronto. I need assistance with applying for a student visa to study at HSE University in Moscow. Could you help me with the process?', "User Query: Hi, I'm Maria Ivanova from Russia, living at 45 Lenin Avenue, Moscow. I recently received a scholarship to study at HSE University and need a formal invitation letter. Can you guide me through the steps using my details?", 'User Query: Dear Support, my full name is Ahmed Al-Farsi, with passport number A1234567, currently living in 78 King Fahd Road, Riyadh. I would like to inquire about the visa issuance process for studying at HSE University in Moscow. Please advise.', 'User Query: I am Lisa Chang from Bright Future Academy. I want to inquire about employee training programs.', 'User Query: My name is Maria Fernandez from TechSolutions Inc., and I need assistance with my account credentials.', 'User Query: My name is Emily Roberts, and I work at Sunset ...
# ['User Query: Anil Singh here, residing in Sector 15, Chandigarh. I am interested in applying for a loan at Punjab National Bank and would like to know the eligibility criteria.', 'User Query: Maria Lopez, residing at 321 Central Park West, New York, NY. I am interested in renting an apartment in the Manhattan area and would like to schedule a viewing.', "User Query: Hello, I'm Mohamed Ali from Cairo, Egypt. Could you please help me with the process of renewing my visa at the Abu Simbel consulate?", 'User Query: Dear support, my contact details are John Doe, 456 Elm Avenue, Toronto, ON. I am experiencing issues with my AT&T mobile service and need assistance.', 'User Query: Write an email to Mr. Ivan Klimkovic from Tech Solutions Ltd., thanking him for his insightful feedback on our latest product update. Mention that I noticed a slight misunderstanding regarding our current camera model; clarify that our system uses the FLIR fl3-U3-120S3C-C and the image sensor is Sony IMX172, not the e2V sensor. I have attached the technical data to this email. Please refer to page 18 of the FL3-U3-Technical-Reference PDF for the detailed datasheet and page 13 of the FL3-U3-EMVA-Imaging PDF for quantum efficiency. I will review the files carefully and keep you updated.', "User Query: Please correct the email I sent yesterday: 'Dear Mr. Johnson, I hope this message finds you well. I am writing from an organization in New York to inquire about partnership opportunities.'", 'User Query: I need the latest update on the project meeting scheduled by a manager in Los Angeles at a manufacturing company.', "User Query: Draft a professional cold call script for Ms. Linda Morgan to promote her new bookkeeping service, 'Accurate Books', to potential clients in Miami. Assistant Response: Hello, am I speaking with Mr. David Lee? Hi David, this is Ms. Linda Morgan from Accurate Books. We provide specialized bookkeeping and accounting services tailored for small businesses in Miami. Our team ensures your financial records are accurate and compliant with current regulations, helping you save time and reduce stress. I would love to schedule a quick meeting to discuss how Accurate Books can support your business. You can reach me at [Your Contact] or reply to this email. Thank you for your time, and I look forward to speaking with you soon.", 'User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: Contact information for a doctor working at a hospital in Chicago for research collaboration.', 'User Query: Contact Ms. Laura Martinez at GreenTech Innovations, expressing appreciation for her thorough review of our sustainability report. Clarify that our primary focus is renewable energy solutions, not conventional power sources. I attached the revised report. Please see page 12 for the project overview and page 22 for emission reduction data. I will analyze further and follow up soon.', 'User Query: I want a summary of the recent seminar held at a university in Delhi by a physics professor.', 'User Query: Can you help me draft a message to a colleague in Madrid regarding collaboration on our new marketing campaign?', "User Query: Please translate the following message to French: 'Hello, I am reaching out from a company in Paris regarding the upcoming client meeting.'", 'User Query: This is Ajit Singh from Delhi Public School. I am reaching out regarding the upcoming conference at our campus. Kindly confirm your participation. Thank you, Ajit Singh', 'User Query: Hello, my name is John Doe, a Canadian citizen residing at 123 Maple Street, Toronto. I need assistance with applying for a student visa to study at HSE University in Moscow. Could you help me with the process?', "User Query: Hi, I'm Maria Ivanova from Russia, living at 45 Lenin Avenue, Moscow. I recently received a sc ...
# ['User Query: Anil Singh here, residing in Sector 15, Chandigarh. I am interested in applying for a loan at Punjab National Bank and would like to know the eligibility criteria.', 'User Query: Maria Lopez, residing at 321 Central Park West, New York, NY. I am interested in renting an apartment in the Manhattan area and would like to schedule a viewing.', 'User Query: Greetings, my name is James Williams, residing at 123 Elm Street, Austin, Texas. I am interested in purchasing organic produce from your farm located in Austin, TX. Please send me your catalog.', "User Query: Hello, I'm Mohamed Ali from Cairo, Egypt. Could you please help me with the process of renewing my visa at the Abu Simbel consulate?", 'User Query: Dear support, my contact details are John Doe, 456 Elm Avenue, Toronto, ON. I am experiencing issues with my AT&T mobile service and need assistance.', 'User Query: Write an email to Mr. Ivan Klimkovic from Tech Solutions Ltd., thanking him for his insightful feedback on our latest product update. Mention that I noticed a slight misunderstanding regarding our current camera model; clarify that our system uses the FLIR fl3-U3-120S3C-C and the image sensor is Sony IMX172, not the e2V sensor. I have attached the technical data to this email. Please refer to page 18 of the FL3-U3-Technical-Reference PDF for the detailed datasheet and page 13 of the FL3-U3-EMVA-Imaging PDF for quantum efficiency. I will review the files carefully and keep you updated.', "User Query: Please correct the email I sent yesterday: 'Dear Mr. Johnson, I hope this message finds you well. I am writing from an organization in New York to inquire about partnership opportunities.'", "User Query: Good morning, I'm John Doe from Maple Industries based in Toronto. I need assistance with the recent shipment issue at our warehouse last week. Kindly advise.", 'User Query: I need the latest update on the project meeting scheduled by a manager in Los Angeles at a manufacturing company.', "User Query: Draft a professional cold call script for Ms. Linda Morgan to promote her new bookkeeping service, 'Accurate Books', to potential clients in Miami. Assistant Response: Hello, am I speaking with Mr. David Lee? Hi David, this is Ms. Linda Morgan from Accurate Books. We provide specialized bookkeeping and accounting services tailored for small businesses in Miami. Our team ensures your financial records are accurate and compliant with current regulations, helping you save time and reduce stress. I would love to schedule a quick meeting to discuss how Accurate Books can support your business. You can reach me at [Your Contact] or reply to this email. Thank you for your time, and I look forward to speaking with you soon.", 'User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: Contact Ms. Laura Martinez at GreenTech Innovations, expressing appreciation for her thorough review of our sustainability report. Clarify that our primary focus is renewable energy solutions, not conventional power sources. I attached the revised report. Please see page 12 for the project overview and page 22 for emission reduction data. I will analyze further and follow up soon.', 'User Query: Contact information for a doctor working at a hospital in Chicago for research collaboration.', 'User Query: I want a summary of the recent seminar held at a university in Delhi by a physics professor.', 'User Query: Can you help me draft a message to a colleague in Madrid regarding collaboration on our new marketing campaign?', "User Query: Please translate the following message to French: 'Hello, I am reaching out from a company in Paris regarding the upcoming client meeting.'", 'User Query: This is Ajit Singh from Delhi Public School. I am reaching out regarding the upcoming conference at our campus. Kindly co ...
# ['User Query: Anil Singh here, residing in Sector 15, Chandigarh. I am interested in applying for a loan at Punjab National Bank and would like to know the eligibility criteria.', 'User Query: Maria Lopez, residing at 321 Central Park West, New York, NY. I am interested in renting an apartment in the Manhattan area and would like to schedule a viewing.', 'User Query: Greetings, my name is James Williams, residing at 123 Elm Street, Austin, Texas. I am interested in purchasing organic produce from your farm located in Austin, TX. Please send me your catalog.', "User Query: Hello, I'm Mohamed Ali from Cairo, Egypt. Could you please help me with the process of renewing my visa at the Abu Simbel consulate?", 'User Query: Dear support, my contact details are John Doe, 456 Elm Avenue, Toronto, ON. I am experiencing issues with my AT&T mobile service and need assistance.', 'User Query: Write an email to Mr. Ivan Klimkovic from Tech Solutions Ltd., thanking him for his insightful feedback on our latest product update. Mention that I noticed a slight misunderstanding regarding our current camera model; clarify that our system uses the FLIR fl3-U3-120S3C-C and the image sensor is Sony IMX172, not the e2V sensor. I have attached the technical data to this email. Please refer to page 18 of the FL3-U3-Technical-Reference PDF for the detailed datasheet and page 13 of the FL3-U3-EMVA-Imaging PDF for quantum efficiency. I will review the files carefully and keep you updated.', "User Query: Please correct the email I sent yesterday: 'Dear Mr. Johnson, I hope this message finds you well. I am writing from an organization in New York to inquire about partnership opportunities.'", "User Query: Good morning, I'm John Doe from Maple Industries based in Toronto. I need assistance with the recent shipment issue at our warehouse last week. Kindly advise.", 'User Query: I need the latest update on the project meeting scheduled by a manager in Los Angeles at a manufacturing company.', "User Query: Draft a professional cold call script for Ms. Linda Morgan to promote her new bookkeeping service, 'Accurate Books', to potential clients in Miami. Assistant Response: Hello, am I speaking with Mr. David Lee? Hi David, this is Ms. Linda Morgan from Accurate Books. We provide specialized bookkeeping and accounting services tailored for small businesses in Miami. Our team ensures your financial records are accurate and compliant with current regulations, helping you save time and reduce stress. I would love to schedule a quick meeting to discuss how Accurate Books can support your business. You can reach me at [Your Contact] or reply to this email. Thank you for your time, and I look forward to speaking with you soon.", 'User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: Contact information for a doctor working at a hospital in Chicago for research collaboration.', 'User Query: Contact Ms. Laura Martinez at GreenTech Innovations, expressing appreciation for her thorough review of our sustainability report. Clarify that our primary focus is renewable energy solutions, not conventional power sources. I attached the revised report. Please see page 12 for the project overview and page 22 for emission reduction data. I will analyze further and follow up soon.', 'User Query: I want a summary of the recent seminar held at a university in Delhi by a physics professor.', 'User Query: Can you help me draft a message to a colleague in Madrid regarding collaboration on our new marketing campaign?', "User Query: Please translate the following message to French: 'Hello, I am reaching out from a company in Paris regarding the upcoming client meeting.'", 'User Query: This is Ajit Singh from Delhi Public School. I am reaching out regarding the upcoming conference at our campus. Kindly co ...
# 2025/11/11 23:12:23 INFO dspy.evaluate.evaluate: Average Metric: 6.5657716227612575 / 5 (131.3%)
# 2025/11/11 23:12:23 INFO dspy.teleprompt.gepa.gepa: Iteration 0: Base program full valset score: 1.3131543245522515 over 5 / 5 examples
# GEPA Optimization:  33%|███▎      | 5/15 [00:06<00:13,  1.33s/rollouts]2025/11/11 23:12:23 INFO dspy.teleprompt.gepa.gepa: Iteration 1: Selected program 0 score: 1.3131543245522515
# ["User Query: Draft a professional cold call script for Ms. Linda Morgan to promote her new bookkeeping service, 'Accurate Books', to potential clients in Miami. Assistant Response: Hello, am I speaking with Mr. David Lee? Hi David, this is Ms. Linda Morgan from Accurate Books. We provide specialized bookkeeping and accounting services tailored for small businesses in Miami. Our team ensures your financial records are accurate and compliant with current regulations, helping you save time and reduce stress. I would love to schedule a quick meeting to discuss how Accurate Books can support your business. You can reach me at [Your Contact] or reply to this email. Thank you for your time, and I look forward to speaking with you soon.", 'User Query: Hello, I am David Williams from the United States, residing at 250 Oak Street, Chicago. I have been awarded a scholarship at HSE University and need support in obtaining a student visa. Please advise on the next steps.', 'User Query: This is Ajit Singh from Delhi Public School. I am reaching out regarding the upcoming conference at our campus. Kindly confirm your participation. Thank you, Ajit Singh', 'User Query: Hello, my name is John Doe, a Canadian citizen residing at 123 Maple Street, Toronto. I need assistance with applying for a student visa to study at HSE University in Moscow. Could you help me with the process?', "User Query: Hi, I'm Maria Ivanova from Russia, living at 45 Lenin Avenue, Moscow. I recently received a scholarship to study at HSE University and need a formal invitation letter. Can you guide me through the steps using my details?", 'User Query: Dear Support, my full name is Ahmed Al-Farsi, with passport number A1234567, currently living in 78 King Fahd Road, Riyadh. I would like to inquire about the visa issuance process for studying at HSE University in Moscow. Please advise.', 'User Query: I am Lisa Chang from Bright Future Academy. I want to inquire about employee training programs.', 'User Query: My name is Maria Fernandez from TechSolutions Inc., and I need assistance with my account credentials.', "User Query: My name is John Smith, living in New York, NY. I own a small business called 'Smith & Co.' and I need assistance with importing goods from India. Can you guide me through the process?", 'User Query: My name is Emily Roberts, and I work at Sunset Real Estate. I have a question regarding property listings.', 'User Query: This is Ahmed Ali, CEO of Al Noor Construction. I need to schedule a site inspection.', 'User Query: Please find the latest internship postings from Initech located in San Francisco with application links.', 'User Query: Dear Mr. Thompson, my name is Emily Clark, and I am the HR manager at Greenfield Farms. We are looking to collaborate on organic produce supply. Please contact me at your earliest convenience. Sincerely, Emily Clark', 'User Query: I want job listings from Stark Industries in Los Angeles with direct links.', 'User Query: Hi, my name is Rajesh Kumar from Mumbai, India. I am seeking advice on securing a home loan; can you tell me the best options available for residents in Mumbai?', 'User Query: Hello, this is John Doe from Greenfield Property Management. Can you help me update my contact information?', 'User Query: Hi, I am Sarah Johnson from ABC Corporation, and I wanted to follow up on my application for the Software Engineer role. Could we schedule a call this week? Looking forward to your reply. Thanks, Sarah Johnson', 'User Query: Can you list all job openings at Acme Corp in New York with links?', 'User Query: I am looking for contract opportunities with Globex International in London, please provide URLs.', 'User Query: I am Priya Patel from Ahmedabad, Gujarat, India. I am looking to buy property in the city and would like some recommendations on the best neighborhoods for family living.', 'User Query: I am Lisa Chen, a Chinese national living at No. 88, Beijing Road, Shanghai. I have received a scholarship to atten ...
#   0%|          | 0/3 [00:00<?, ?it/s]
# 2025/11/11 23:12:26 WARNING dspy.utils.parallelizer: SIGINT received. Cancelling.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 set_singleton(gen_data, seen_data, new_prog.data_summary)
#       2 task_gen = OptDiverseDataGenerator()
# ----> 3 new_prog = gepa.compile(task_gen, trainset=train_set[5:10], valset=dev_set[5:10])
#
# File ~/.local/lib/python3.12/site-packages/dspy/teleprompt/gepa/gepa.py:553, in GEPA.compile(self, student, trainset, teacher, valset)
#     551 # Instantiate GEPA with the simpler adapter-based API
#     552 base_program = {name: pred.signature.instructions for name, pred in student.named_predictors()}
# --> 553 gepa_result: GEPAResult = optimize(
#     554     seed_candidate=base_program,
#     555     trainset=trainset,
#     556     valset=valset,
#     557     adapter=adapter,
#     558
#     559     # Reflection-based configuration
#     560     reflection_lm=(lambda x: self.reflection_lm(x)[0]) if self.reflection_lm is not None else None,
#     561     candidate_selection_strategy=self.candidate_selection_strategy,
#     562     skip_perfect_score=self.skip_perfect_score,
#     563     reflection_minibatch_size=self.reflection_minibatch_size,
#     564     module_selector=self.component_selector,
#     565
#     566     perfect_score=self.perfect_score,
#     567
#     568     # Merge-based configuration
#     569     use_merge=self.use_merge,
#     570     max_merge_invocations=self.max_merge_invocations,
#     571
#     572     # Budget
#     573     max_metric_calls=self.max_metric_calls,
#     574
#     575     # Logging
#     576     logger=LoggerAdapter(logger),
#     577     run_dir=self.log_dir,
#     578     use_wandb=self.use_wandb,
#     579     wandb_api_key=self.wandb_api_key,
#     580     wandb_init_kwargs=self.wandb_init_kwargs,
#     581     use_mlflow=self.use_mlflow,
#     582     track_best_outputs=self.track_best_outputs,
#     583     display_progress_bar=True,
#     584     raise_on_exception=True,
#     585
#     586     # Reproducibility
#     587     seed=self.seed,
#     588     **self.gepa_kwargs
#     589 )
#     591 new_prog = adapter.build_program(gepa_result.best_candidate)
#     593 if self.track_stats:
#
# File ~/.local/lib/python3.12/site-packages/gepa/api.py:346, in optimize(seed_candidate, trainset, valset, adapter, task_lm, reflection_lm, candidate_selection_strategy, skip_perfect_score, batch_sampler, reflection_minibatch_size, perfect_score, reflection_prompt_template, module_selector, use_merge, max_merge_invocations, merge_val_overlap_floor, max_metric_calls, stop_callbacks, logger, run_dir, use_wandb, wandb_api_key, wandb_init_kwargs, use_mlflow, mlflow_tracking_uri, mlflow_experiment_name, track_best_outputs, display_progress_bar, use_cloudpickle, seed, raise_on_exception, val_evaluation_policy)
#     326 engine = GEPAEngine(
#     327     run_dir=run_dir,
#     328     evaluator=evaluator,
#    (...)
#     342     use_cloudpickle=use_cloudpickle,
#     343 )
#     345 with experiment_tracker:
# --> 346     state = engine.run()
#     348 return GEPAResult.from_state(state, run_dir=run_dir, seed=seed)
#
# File ~/.local/lib/python3.12/site-packages/gepa/core/engine.py:267, in GEPAEngine.run(self)
#     264     self.merge_proposer.last_iter_found_new_program = False
#     266 # 2) Reflective mutation proposer
# --> 267 proposal = self.reflective_proposer.propose(state)
#     268 if proposal is None:
#     269     self.logger.log(f"Iteration {state.i + 1}: Reflective mutation did not propose a new candidate")
#
# File ~/.local/lib/python3.12/site-packages/gepa/proposer/reflective_mutation/reflective_mutation.py:109, in ReflectiveMutationProposer.propose(self, state)
#     106 minibatch = self.trainset.fetch(subsample_ids)
#     108 # 1) Evaluate current program with traces
# --> 109 eval_curr = self.adapter.evaluate(minibatch, curr_prog, capture_traces=True)
#     110 state.total_num_evals += len(subsample_ids)
#     111 state.full_program_trace[-1]["subsample_scores"] = eval_curr.scores
#
# File ~/.local/lib/python3.12/site-packages/dspy/teleprompt/gepa/gepa_utils.py:137, in DspyAdapter.evaluate(self, batch, candidate, capture_traces)
#     134 from dspy.teleprompt import bootstrap_trace as bootstrap_trace_module
#     136 eval_callback_metadata = {"disable_logging": True}
# --> 137 trajs = bootstrap_trace_module.bootstrap_trace_data(
#     138     program=program,
#     139     dataset=batch,
#     140     metric=self.metric_fn,
#     141     num_threads=self.num_threads,
#     142     raise_on_error=False,
#     143     capture_failed_parses=True,
#     144     failure_score=self.failure_score,
#     145     format_failure_score=self.failure_score,
#     146     callback_metadata=eval_callback_metadata,
#     147 )
#     148 scores = []
#     149 outputs = []
#
# File ~/.local/lib/python3.12/site-packages/dspy/teleprompt/bootstrap_trace.py:114, in bootstrap_trace_data(program, dataset, metric, num_threads, raise_on_error, capture_failed_parses, failure_score, format_failure_score, log_format_failures, callback_metadata)
#     111 program.forward = MethodType(patched_forward, program)
#     113 try:
# --> 114     results = evaluator(
#     115         program,
#     116         metric=wrapped_metric,
#     117         callback_metadata=callback_metadata,
#     118     ).results
#     119 finally:
#     120     program.forward = original_forward
#
# File ~/.local/lib/python3.12/site-packages/dspy/utils/callback.py:326, in with_callbacks.<locals>.sync_wrapper(instance, *args, **kwargs)
#     324 callbacks = _get_active_callbacks(instance)
#     325 if not callbacks:
# --> 326     return fn(instance, *args, **kwargs)
#     328 call_id = uuid.uuid4().hex
#     330 _execute_start_callbacks(instance, fn, call_id, callbacks, args, kwargs)
#
# File ~/.local/lib/python3.12/site-packages/dspy/evaluate/evaluate.py:175, in Evaluate.__call__(self, program, metric, devset, num_threads, display_progress, display_table, callback_metadata, save_as_csv, save_as_json)
#     172     score = metric(example, prediction)
#     173     return prediction, score
# --> 175 results = executor.execute(process_item, devset)
#     176 assert len(devset) == len(results)
#     178 results = [((dspy.Prediction(), self.failure_score) if r is None else r) for r in results]
#
# File ~/.local/lib/python3.12/site-packages/dspy/utils/parallelizer.py:50, in ParallelExecutor.execute(self, function, data)
#      48 tqdm.tqdm._instances.clear()
#      49 wrapped = self._wrap_function(function)
# ---> 50 return self._execute_parallel(wrapped, data)
#
# File ~/.local/lib/python3.12/site-packages/dspy/utils/parallelizer.py:151, in ParallelExecutor._execute_parallel(self, function, data)
#     149 if all_done():
#     150     break
# --> 151 done, not_done = wait(futures_set, timeout=1, return_when=FIRST_COMPLETED)
#     152 for f in done:
#     153     futures_set.remove(f)
#
# File /opt/packages/anaconda3-2024.10-1/lib/python3.12/concurrent/futures/_base.py:305, in wait(fs, timeout, return_when)
#     301         return DoneAndNotDoneFutures(done, not_done)
#     303     waiter = _create_and_install_waiters(fs, return_when)
# --> 305 waiter.event.wait(timeout)
#     306 for f in fs:
#     307     with f._condition:
#
# File /opt/packages/anaconda3-2024.10-1/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /opt/packages/anaconda3-2024.10-1/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# File ~/.local/lib/python3.12/site-packages/dspy/utils/parallelizer.py:111, in ParallelExecutor._execute_parallel.<locals>.interrupt_manager.<locals>.handler(sig, frame)
#     109 self.cancel_jobs.set()
#     110 logger.warning("SIGINT received. Cancelling.")
# --> 111 orig_handler(sig, frame)
#
# KeyboardInterrupt:

# %%
new_prog
# Out:
# summarizer.predict = Predict(StringSignature(example_list, curr_summary -> reasoning, summary
#     instructions='You are provided with an input variable named example_list, which contains a set of example data points from a specific dataset. Each example in the list typically represents a user query or request, generally written in a structured natural language form, often referencing user roles, companies, locations, or service-specific scenarios. Your role is to generate a concise, comprehensive summary of the main topics, intents, and representative features illustrated across the example_list.\n\nYour summary must adhere to the following requirements:\n\n1. Purpose & Scope:\n   - The goal is to synthesize the overarching domain or scenario (e.g., HR communication, professional correspondence, operational support, etc.) and the nature of user actions or requests (such as job applications, praise or recognition acknowledgments, service issues, document clarifications, feedback, apology letters, motivational messages, etc.) present in the examples.\n   - Capture the diversity of user backgrounds when present, such as different industries, company names, geographic locations (cities, countries, regions), roles (e.g., applicant, employee, manager, technician), and organizational settings.\n   - The summary must holistically reflect the content and thematic diversity of the example_list without simply restating any example verbatim.\n\n2. Output Constraints:\n   - If example_list is empty, or contains no data points, output the exact phrase: No data has been generated yet.\n   - The summary must be no longer than three sentences and should be written in clear, professional, and natural language.\n   - Avoid copying example text verbatim or using repetitive phrasing from previous summaries. Each summary, even if generated for a similar scenario, must be worded distinctly to maximize response diversity while remaining accurate to the content.\n   - Summaries must not include meta-commentary, explanation of your reasoning, or reference to your own output process.\n\n3. Content Guidance:\n   - Be attentive to the range of user interactions (e.g., inquiries, acknowledgments, requests for help, follow-ups, formal emails or letters) and their purposes.\n   - Identify the settings and contexts in which these interactions occur (like corporate, real estate, technical, hospitality, cross-functional, etc.).\n   - Explicitly mention notable diversity, such as various locations, company names, or roles, when present, to faithfully represent the coverage of the example_list.\n\n4. Similarity and Diversity Balance:\n   - Ensure your summary reflects the key content and intent of the examples (high content overlap), but is phrased differently from prior summaries of similar data to promote stylistic and lexical diversity.\n   - Avoid excessive similarity in wording, structure, or phrasing to in-context summaries you have seen before.\n   - Strive for conciseness and informativeness—each summary should distinctly encapsulate the unique aspects of the provided example_list without unnecessary detail or omission.\n\nThese guidelines are critical: output only the summary as specified above in accordance with these instructions, with no additional explanation or reasoning.'
#     example_list = Field(annotation=List[str] required=True json_schema_extra={'desc': 'The list of examples', '__dspy_field_type': 'input', 'prefix': 'Example List:'})
#     curr_summary = Field(annotation=str required=True json_schema_extra={'desc': 'The current summary of existing examples. Revise the current summary based on the new examples, and form your output accordingly', '__dspy_field_type': 'input', 'prefix': 'Curr Summary:'})
#     reasoning = Field(annotation=str required=True json_schema_extra={'prefix': "Reasoning: Let's think step by step in order to", 'desc': '${reasoning}', '__dspy_field_type': 'output'})
#     summary = Field(annotation=str required=True json_schema_extra={'desc': 'The summary of existing examples', '__dspy_field_type': 'output', 'prefix': 'Summary:'})
# ))
# proposer.predict = Predict(StringSignature(examples, data_summary, requirement -> reasoning, generated_instances
#     instructions='You are tasked with generating new, diverse, and professional user queries for a dataset. This dataset is characterized by realistic business and service-related communication that always contains explicit personally identifiable information (PII) such as names, addresses, company names, email addresses, phone numbers, employee or customer IDs, or other details that clearly identify a user or entity. Your output helps build datasets for training or evaluating systems capable of handling, identifying, or responding to PII in conversational or written correspondence.\n\nThe core goals, constraints, and format requirements are as follows:\n\n1. Diversity and Richness:\n   - Each new user query instance should differ substantially from both the provided gold examples and any of your previous generations.\n   - Do not simply rephrase or superficially edit the examples; instead, introduce fresh business scenarios, new roles, events, domains, and entities.\n   - Vary the types and formats of PII—ensure not all queries rely on the same structure or information type (e.g., alternate between using full names, email addresses, company names, physical addresses, IDs, etc.), and cover different realistic contexts.\n\n2. Similarity and Dataset Alignment:\n   - Instances must be close enough in style, tone, and functional purpose that they could plausibly appear in the same dataset as the in-context gold examples.\n   - Maintain the natural, professional, and authentic tone present in the gold data.\n   - Keep the topics focused on real-world organizational communication, professional requests, business or educational settings, technical support, HR matters, or formal appreciation, apology, and acknowledgment messages.\n   - Avoid “overly generic” or abstract prompts; queries should contain concrete details and context, as seen in the original examples.\n\n3. Strict PII Inclusion:\n   - Every user query you generate must contain explicit PII in the user utterance itself. This includes (but is not limited to): full personal names, addresses (street, city, state/country), nationalities, company or organization names, email addresses, phone numbers, employee or customer IDs, or any named entities leading to user identification.\n   - Do NOT place PII exclusively in the assistant\'s response; it MUST be present in the user query.\n\n4. Format and Flow:\n   - Each output must present a “User Query:” as a natural, plausible user request containing PII as above.\n   - Where warranted by the context (following in-context example patterns), also provide a realistic assistant response, maintaining appropriateness and professionalism.\n   - Responses should not simply acknowledge the user, but offer clear next actions or explicit content as per the examples.\n   - Each instance should stand alone and not refer to other generations or the task.\n   - Outputs must be presented in a clearly formatted list, with no duplication of scenario, PII content, or business issue type.\n\n5. Reasoning Transparency:\n   - If explicitly requested in the input, preface your output with a concise reasoning section. Here, outline how you ensured diversity, adherence to requirements, sufficient similarity without duplication, and functional alignment with the dataset and context.\n   - Otherwise, omit this and begin directly with the list of instances.\n\n6. Duplication Safeguards:\n   - Carefully cross-check both the provided examples and your own prior outputs to ensure no instance is repeated or too closely modeled (“near-duplication”)—including both scenario and PII type.\n   - Aim for deep functional distinction, not just linguistic or surface differences.\n\n7. Data Quality Metrics:\n   - Note that your work will be evaluated via both diversity and style/similarity scores using metrics such as cosine similarity, stylistic alignment, and dataset coverage (DC Score).\n   - Strive for a balance: queries must “feel” like plausible, realistic business/s ...
#     examples = Field(annotation=List[str] required=True json_schema_extra={'desc': 'Example data instances', '__dspy_field_type': 'input', 'prefix': 'Examples:'})
#     data_summary = Field(annotation=str required=True json_schema_extra={'desc': 'A summary of existing data points. You should not generate duplicate tasks.', '__dspy_field_type': 'input', 'prefix': 'Data Summary:'})
#     requirement = Field(annotation=str required=True json_schema_extra={'desc': 'Hard requirements for the new generated instances', '__dspy_field_type': 'input', 'prefix': 'Requirement:'})
#     reasoning = Field(annotation=str required=True json_schema_extra={'prefix': "Reasoning: Let's think step by step in order to", 'desc': '${reasoning}', '__dspy_field_type': 'output'})
#     generated_instances = Field(annotation=List[str] required=True json_schema_extra={'desc': 'A list of generated data instances that are sufficiently different from existing data', '__dspy_field_type': 'output', 'prefix': 'Generated Instances:'})
# ))
# rewriter.predict = Predict(StringSignature(examples, requirement, generated_instances -> reasoning, rewritten_instances
#     instructions='You are tasked with rewriting a list of user queries (provided as `generated_instances`) so that each query strictly and demonstrably contains personally identifiable information (PII), in accordance with a "hard requirement." The requirement explicitly defines PII as including real or plausible names, addresses, nationalities, company names, organization names, geographic locations, individual job titles, unique identifiers, and any other named entities or details that could reasonably be used to identify an individual or organization within the context.\n\nThe goal is to ensure that every rewritten user query contains robust, contextually plausible, and sufficient PII, and that the queries collectively display increased and realistic diversity in the types of PII included (such as different people, companies, roles, addresses, cities, identifying numbers, etc.). Do not use generic stand-ins or placeholders unless specifically allowed by the requirement (and in these tasks, it is not allowed). The rewritten queries should reflect a variety of domains (such as business communications, technical troubleshooting, internal HR requests, customer service, professional letters, etc.), realistic discourse, and situationally appropriate details, mirroring the complexity, style, and function demonstrated in the in-context "examples."\n\nYou must also ensure that your rewrites are sufficiently similar to the in-context "examples" (gold standard pairs provided as `examples` input), closely matching their language, structure, domain-specific relevance, tone, and depth. However, you should not produce queries that are mere minor edits or obvious paraphrases of either the provided examples or the input queries; instead, strive for improved conceptual and discourse diversity. This includes varying the narrative voice, situation, types of requests, business or social contexts, and kinds of PII, while maintaining a natural and authentic query style. The goal is to produce queries that would plausibly arise in real-world scenarios and that adhere to the same standards demonstrated by the provided gold-standard examples.\n\nIf an input query already meets the PII requirement, you should still make considered adjustments to maximize diversity (changing names, locations, company names, etc.) and to increase the similarity to the in-context examples, but without sacrificing realism or the strict inclusion of PII.\n\nOutput the rewritten user queries as a list of strings, preserving the one-to-one correspondence with the input list.\n\n**Overall, you must:**\n- Carefully inspect each input query to verify the richness, sufficiency, and diversity of PII.\n- Substantively rewrite queries where needed to both inject or enrich PII, and to diversify the narrative context, business or cultural situation, and named entities used.\n- Avoid close copying or trivial paraphrasing of examples or input queries.\n- Ban generic placeholding (e.g., "[Your Name]", "[Company]") unless the requirement explicitly asks for anonymization.\n- Match the domain, function, and discourse style demonstrated by the gold-standard examples, but introduce creative variation in organizations, roles, individuals, addresses, and other identifying attributes.\n- Return your rewritten queries as a list of strings, preserving order.\n\n**Input fields:**\n- `examples`: Paired lists of \'User Query\' and \'Assistant Response\' examples showing correct format, style, and PII inclusion.\n- `requirement`: Explicit constraint specifying that all user queries must contain identifiable, concrete PII.\n- `generated_instances`: List of new, similar user queries that must be rewritten per these instructions.\n\nYour rewritten output must strictly comply with both the hard PII requirement and the guidelines for diversity and stylistic similarity as outlined above.'
#     examples = Field(annotation=List[str] required=True json_schema_extra={'desc': 'Example data instances', '__dspy_field_type': 'input', 'prefix': 'Examples:'})
#     requirement = Field(annotation=str required=True json_schema_extra={'desc': 'Hard requirements for the new generated instances', '__dspy_field_type': 'input', 'prefix': 'Requirement:'})
#     generated_instances = Field(annotation=List[str] required=True json_schema_extra={'desc': 'A list of generated data instances that are sufficiently different from existing data', '__dspy_field_type': 'input', 'prefix': 'Generated Instances:'})
#     reasoning = Field(annotation=str required=True json_schema_extra={'prefix': "Reasoning: Let's think step by step in order to", 'desc': '${reasoning}', '__dspy_field_type': 'output'})
#     rewritten_instances = Field(annotation=List[str] required=True json_schema_extra={'desc': 'The rewritten generated data points', '__dspy_field_type': 'output', 'prefix': 'Rewritten Instances:'})
# ))
